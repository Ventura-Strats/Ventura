# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

####################################################################################################
### Retrieves account information (NAV, positions, etc) from IB
### And saves it into csv files because we don't know how to export to DB for now
####################################################################################################
script_name = "IB_Account_Data"
max_time_hours = 1 / 60

# %%
####################################################################################################
### Imports
####################################################################################################
from ibapi.wrapper import EWrapper
from ibapi.client import EClient
import init
import utils as ut
import execution_utils as xu
import db
import pandas as pd
# Out:
# ####################################################################################################
# ### Main initialization - Start                                              2023-08-28 07:19:47 ###
# ####################################################################################################
# ### Script Name: execution_utils                                             2023-08-28 07:19:47 ###
# ### Script PID: 3118684                                                      2023-08-28 07:19:47 ###
# ### Initializating application parameters                                    2023-08-28 07:19:47 ###
# ### This computer: H                                                         2023-08-28 07:19:47 ###
# ### System date: 2023-08-28                                                  2023-08-28 07:19:47 ###
# ### Current directory: /home/fls/Models/Ventura/HD/Scripts/Python            2023-08-28 07:19:47 ###

# %%
####################################################################################################
### Script initialization
####################################################################################################
init.scriptInit(script_name, max_time_hours)
# Out:
# ####################################################################################################
# ### Main initialization - Start                                              2023-08-28 08:07:54 ###
# ####################################################################################################
# ### Script Name: IB_Account_Data                                             2023-08-28 08:07:54 ###
# ### Script PID: 3118684                                                      2023-08-28 08:07:54 ###
# ### Initializating application parameters                                    2023-08-28 08:07:54 ###
# ### This computer: H                                                         2023-08-28 08:07:54 ###
# ### System date: 2023-08-28                                                  2023-08-28 08:07:54 ###
# ### Current directory: /home/fls/Models/Ventura/HD/Scripts/Python            2023-08-28 08:07:54 ###
# ### Loading main data tables                                                 2023-08-28 08:07:54 ###
# ####################################################################################################
# ### Main initialization - Done                                               2023-08-28 08:07:54 ###
# ####################################################################################################
# ####################################################################################################
# ### Good to start: True                                                      2023-08-28 08:07:54 ###
# ####################################################################################################
# True

# %%
####################################################################################################
### Script variables
####################################################################################################
account_id_list = [1,2]
file_path = init.DIRECTORY_DATA + "Account_Data/"
file_path_account = file_path + "Account/"
file_path_px_position = file_path + "Px_Position/"
columns_px_position = ["account_id", "conid", "symbol", "secType", "primaryExchange", 
    "currency", "price", "position"]

# %%
####################################################################################################
### Classes
####################################################################################################
class IBAppBook(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)
        self.account_data = pd.DataFrame()
        self.px_position = pd.DataFrame()

    def error(self, reqId, errorCode, errorString, advancedOrderRejectJson):
        print("IB Error ", reqId, " ", errorCode, " ", errorString)
        if errorCode == 502:
            ut.printBanner("Error - Not connected - exiting", False)
            self.stop()
    
    def nextValidId(self, orderId):
        print("Start")
        self.start()     

    def addPxPositionRow(self, contract, price, position):
     #   print("addPxPositionRow")
        try:
            dat = pd.DataFrame({
                "contract":[contract],
                "price":[price],
                "position":[position]
                })
            self.px_position = pd.concat([self.px_position, dat])
        except:
            pass
        
    def addAccountDataRow(self, key, value, ccy):
    #    print("addAccountDataRow")
    #    print([key, value, ccy])
        dat = pd.DataFrame({
            "key":[key],
            "value":[value],
            "ccy":[ccy]
            })
        self.account_data = pd.concat([self.account_data, dat])
        
    def updatePortfolio(self, contract: Contract, position: float, marketPrice: float, marketValue: float,
                        averageCost: float, unrealizedPNL: float, realizedPNL: float, accountName: str):
        print("updatePortfolio")
        print([contract, position, marketPrice, marketValue, 
            averageCost, unrealizedPNL, realizedPNL, accountName])
        self.addPxPositionRow(contract, marketPrice, position) 
        
    def updateAccountValue(self, key, val, currency, accountName):
    #    print("updateAccountValue")
    #    print([key, val, currency])
        self.addAccountDataRow(key, val, currency)
    
    def accountDownloadEnd(self, account):
        print("accountDownloadEnd")
        self.finalFormatting()
        self.stop()
        
    def finalFormatting(self):
        print("finalFormatting")
        print(self.px_position)
        if len(self.px_position) > 0:
            self.px_position = formatPxPositionTable(self.px_position, self.account_id)

    def start(self):
        print("start")
        self.reqAccountUpdates(True, "")
        
    def stop(self):
        print("stop")
        self.reqAccountUpdates(False, "")
        self.done = True
        self.disconnect()

# %%
####################################################################################################
### Sub routines
####################################################################################################
def correctFTSEPrice(dat):
    # TO BE CORRECTED WITH A 'MULTIPLIER' PARAMETER IN static_future_contract
    pos_ftse = (dat["symbol"] == "Z")
    dat.price[pos_ftse] = 100 * dat.price[pos_ftse]
    return dat

def formatPxPositionTable(dat, account_id):
    print(dat)
    dat = dat \
        .assign(
            account_id = account_id,
            conid = dat.contract.map(lambda x: x.conId),
            symbol = dat.contract.map(lambda x: x.symbol),
            secType = dat.contract.map(lambda x: x.secType),
            primaryExchange = dat.contract.map(lambda x: x.primaryExchange),
            currency = dat.contract.map(lambda x: x.currency)
            ) \
        [columns_px_position]
    dat = correctFTSEPrice(dat)
    return dat

@ut.tryDiagnosticDat()
def saveAccountFile(dat, account_id):
    file_name = f"account_{account_id}_{init.char_start_time}.csv"
    dat.to_csv(file_path_account + file_name, index=False)
    file_name = f"account_{account_id}_last.csv"
    dat.to_csv(file_path_account + file_name, index=False)
    return dat

@ut.tryDiagnosticDat()    
def savePxPositionFile(dat, account_id):
    file_name = f"px_position_{account_id}_{init.char_start_time}.csv"
    dat.to_csv(file_path_px_position + file_name, index=False)
    file_name = f"px_position_{account_id}_last.csv"
    dat.to_csv(file_path_px_position + file_name, index=False)
    return dat

def tryToFindQuoteInUSD(dat_px_position, ccy_account):
    return dat_px_position[
        (dat_px_position["secType"] == "CASH")
        & (dat_px_position["symbol"] == ccy_account)
        & (dat_px_position["currency"] == "USD")
    ]

def tryToConvertFXRateToUSDUsingAccount(dat_account, ccy_account):
    fx_account = float(dat_account[
        (dat_account["key"] == "ExchangeRate")
        & (dat_account["ccy"] == ccy_account)
    ]["value"].values[0])
    fx_usd = float(dat_account[
        (dat_account["key"] == "ExchangeRate")
        & (dat_account["ccy"] == "USD")
    ]["value"].values[0])
    return fx_account / fx_usd
    

def findUSDQuotedInCCY(dat_px_position, ccy_account):
    dat_fx = dat_px_position[
        (dat_px_position["secType"] == "CASH")
        & (dat_px_position["symbol"] == "USD")
        & (dat_px_position["currency"] == ccy_account)
    ]
    fx = 1 / float(dat_fx["price"].values[0])
    return fx

def findFXinPxPosition(dat_px_position, account_id):
    ACCOUNTS = db.loadTableLocal("account")
    ccy_id_account = ACCOUNTS["ccy_id"][ACCOUNTS["account_id"] == account_id].values[0]

    ccy_account = init.CURRENCIES["ccy"][init.CURRENCIES["ccy_id"] == ccy_id_account].values[0]

    dat_fx = tryToFindQuoteInUSD(dat_px_position, ccy_account)
    if len(dat_fx) > 0:
        fx = float(dat_fx["price"].values[0])
    else:
        fx = findUSDQuotedInCCY(dat_px_position, ccy_account)
    return fx

def findFXinAccount(dat_account, account_id):
    ACCOUNTS = db.loadTableLocal("account")
    ccy_id_account = ACCOUNTS["ccy_id"][ACCOUNTS["account_id"] == account_id].values[0]
    ccy_account = init.CURRENCIES["ccy"][init.CURRENCIES["ccy_id"] == ccy_id_account].values[0]
    fx = tryToConvertFXRateToUSDUsingAccount(dat_account, ccy_account)
    return fx

# %%
@ut.tryDiagnosticDat()
def saveNAVToDB(dat_account, dat_px_position, account_id):
    nav = float(dat_account["value"][dat_account["key"] == "NetLiquidation"].values[0])
    fx = findFXinAccount(dat_account, account_id)
    nav_usd = nav * fx

    sql_q = """INSERT INTO book_nav
        (account_id, date, timestamp, nav_ccy, nav_usd)
        VALUES ({}, '{}', '{}', {}, {})""".format(
            account_id,
            init.TODAY_STR,
            init.char_start_time,
            nav,
            nav_usd
        )
    db.executeSQL(sql_q)

    sql_q = """SELECT * FROM book_nav 
        WHERE account_id = {} AND date = '{}' AND timestamp = '{}'""".format(
            account_id,
            init.TODAY_STR,
            init.char_start_time
        )
    return db.select(sql_q)

def extractAccountFXData(dat_i, dat_fx):
    dat_fx_i = dat_i[
        (dat_i["key"] == "ExchangeRate") 
            & (dat_i["ccy"] != "BASE")
         ] \
        .assign(value = lambda x: float(x.value))
    fx_usd = dat_fx_i[dat_fx_i["ccy"] == "USD"]["value"].values[0]
    dat_fx_i["value"] = dat_fx_i["value"].apply(lambda x: x / fx_usd)
    return pd.concat([dat_fx, dat_fx_i])

def extractAccountPositionData(dat_i, dat_pos, account_id):
    dat_pos_i = dat_i[
        (dat_i["key"] == "TotalCashBalance")
            & (dat_i["ccy"] != "BASE")
        ] \
        .assign(
            account_id = account_id,
            value = lambda x: float(x.value)
            )
    
    return pd.concat([dat_pos, dat_pos_i])

def formatFXPrices(dat_fx):
    return dat_fx \
        .drop("key", axis=1) \
        .rename({"ccy":"code", "value":"price"}, axis=1) \
        .groupby("code", as_index=False).agg({"price":"mean"}) \
        .merge(init.ASSETS, on="code", how="left") \
        .assign(timestamp = init.char_start_time) \
        [["asset_id", "timestamp", "price"]]

def formatPositions(dat_pos, dat_fx): 
    return dat_pos \
       .drop("key", axis=1) \
       .rename({"ccy":"code", "value":"position"}, axis=1) \
       .merge(init.ASSETS, on="code", how="left") \
       .assign(
           timestamp = init.char_start_time,
           position = lambda x: float(x.position)
           ) \
       [["account_id", "asset_id", "timestamp", "position"]]
    
@ut.tryDiagnosticNone()
def saveFXPxPositionIntoDB():
    dat_fx = pd.DataFrame()
    dat_pos = pd.DataFrame()
    for account_id in account_id_list:
        file_name = "account_{}_{}.csv".format(account_id, init.char_start_time)
        dat_i = pd.read_csv(file_path_account + file_name)        
        dat_fx = extractAccountFXData(dat_i, dat_fx)
        dat_pos = extractAccountPositionData(dat_i, dat_pos, account_id)

    dat_fx = formatFXPrices(dat_fx)
    db.appendToTable("live_px_fx_book", dat_fx)
        
    dat_pos = formatPositions(dat_pos, dat_fx)
    db.appendToTable("book_live_position_fx", dat_pos)
    return [dat_fx, dat_pos]

def extractAccountFutureData(dat_i, dat_fut):
    # dat_fut_i = dat_i[dat_i["secType"] == "FUT"]
    # dat_fut_i["account_id"] = dat_fut_i["account_id"].map(int)
    # dat_fut_i["conid"] = dat_fut_i["conid"].map(int)
    # dat_fut_i["price"] = dat_fut_i["price"].map(float)
    # dat_fut_i["position"] = dat_fut_i["position"].map(float)
    # dat_fut_i = dat_fut_i[["account_id", "conid", "price", "position"]]
    # return dat_fut_i
    
    return dat_i \
        [dat_i["secType"] == "FUT"] \
        .assign(
            account_id = dat_i.account_id.map(int),
            conid = dat_i.conid.map(int),
            price = dat_i.price.map(float),
            position = dat_i.position.map(float)
            ) \
        [["account_id", "conid", "price", "position"]]

def formatFuturePrices(dat):
    dat_px = dat.groupby("conid", as_index=False).agg({"price":"mean"})
    dat_px["timestamp"] = init.char_start_time
    dat_px = dat_px[["conid", "timestamp", "price"]]
    return dat_px

def formatFuturePositions(dat):
    dat["timestamp"] = init.char_start_time
    dat = dat[["account_id", "conid", "timestamp", "position"]]
    return dat

@ut.tryDiagnosticNone()
def saveFuturePxPositionIntoDB():
    dat_fut = pd.DataFrame()
    for account_id in account_id_list:
        file_name = "px_position_{}_{}.csv".format(account_id, init.char_start_time)
        dat_i = pd.read_csv(file_path_px_position + file_name)        
        dat_fut = extractAccountFXData(dat_i, dat_fut)
    
    dat_px = formatFuturePrices(dat_fut)
    db.appendToTable("live_px_future", dat_px)
        
    dat_pos = formatFuturePositions(dat_fut)
    db.appendToTable("book_live_position_future", dat_pos)
    return [dat_px, dat_pos]

@ut.tryDiagnosticNone()
def getBookLivePriceAndPositions(account_id):
    ut.printBanner("Retrieving data for account " + str(account_id))
    ib_app = IBAppBook()
    ib_port = xu.getIBPort(account_id)
    ib_client_id = xu.getIBClientId(script_name)
    ib_app.connect("127.0.0.1", ib_port, ib_client_id)
    ib_app.account_id = account_id
    ib_app.run()    
    global AAA
    AAA = ib_app.px_position
    saveAccountFile(ib_app.account_data, account_id)
    savePxPositionFile(ib_app.px_position, account_id)
    saveNAVToDB(ib_app.account_data, ib_app.px_position, account_id)

# %%
####################################################################################################
### Script
####################################################################################################
if __name__ == "__main__":
    for account_id in account_id_list:
        getBookLivePriceAndPositions(account_id)
    saveFXPxPositionIntoDB()
#    saveFuturePxPositionIntoDB()
    init.scriptFinish(script_name)
# Out:
# ####################################################################################################
# ### getBookLivePriceAndPositions - Starting                                  2023-08-28 08:09:36 ###
# ####################################################################################################
# ### Retrieving data for account 1                                            2023-08-28 08:09:36 ###
# ####################################################################################################
# IB Error  -1   2104   Market data farm connection is OK:cafarm
# IB Error  -1   2104   Market data farm connection is OK:hfarm
# IB Error  -1   2104   Market data farm connection is OK:eufarmnj
# IB Error  -1   2104   Market data farm connection is OK:cashfarm
# IB Error  -1   2104   Market data farm connection is OK:usfuture
# IB Error  -1   2104   Market data farm connection is OK:usfuture.nj
# IB Error  -1   2104   Market data farm connection is OK:usfarm.nj
# IB Error  -1   2104   Market data farm connection is OK:jfarm
# IB Error  -1   2104   Market data farm connection is OK:eufarm
# IB Error  -1   2104   Market data farm connection is OK:usfarm
# IB Error  -1   2106   HMDS data farm connection is OK:euhmds
# IB Error  -1   2106   HMDS data farm connection is OK:ushmds.nj
# IB Error  -1   2106   HMDS data farm connection is OK:cashhmds
# IB Error  -1   2106   HMDS data farm connection is OK:hkhmds
# IB Error  -1   2106   HMDS data farm connection is OK:fundfarm
# IB Error  -1   2106   HMDS data farm connection is OK:ushmds
# IB Error  -1   2158   Sec-def data farm connection is OK:secdefnj
# ['AccountCode', 'U6861179', '']
# ['AccountCode', 'U6861179', '']
# ['AccountOrGroup', 'U6861179', 'AUD']
# ['AccountOrGroup', 'U6861179', 'AUD']
# ['AccountOrGroup', 'U6861179', 'BASE']
# ['AccountOrGroup', 'U6861179', 'BASE']
# ['AccountOrGroup', 'U6861179', 'CAD']
# ['AccountOrGroup', 'U6861179', 'CAD']
# ['AccountOrGroup', 'U6861179', 'CHF']
# ['AccountOrGroup', 'U6861179', 'CHF']
# ['AccountOrGroup', 'U6861179', 'CNH']
# ['AccountOrGroup', 'U6861179', 'CNH']
# ['AccountOrGroup', 'U6861179', 'CZK']
# ['AccountOrGroup', 'U6861179', 'CZK']
# ['AccountOrGroup', 'U6861179', 'EUR']
# ['AccountOrGroup', 'U6861179', 'EUR']
# ['AccountOrGroup', 'U6861179', 'GBP']
# ['AccountOrGroup', 'U6861179', 'GBP']
# ['AccountOrGroup', 'U6861179', 'HKD']
# ['AccountOrGroup', 'U6861179', 'HKD']
# ['AccountOrGroup', 'U6861179', 'HUF']
# ['AccountOrGroup', 'U6861179', 'HUF']
# ['AccountOrGroup', 'U6861179', 'ILS']
# ['AccountOrGroup', 'U6861179', 'ILS']
# ['AccountOrGroup', 'U6861179', 'JPY']
# ['AccountOrGroup', 'U6861179', 'JPY']
# ['AccountOrGroup', 'U6861179', 'KRW']
# ['AccountOrGroup', 'U6861179', 'KRW']
# ['AccountOrGroup', 'U6861179', 'NOK']
# ['AccountOrGroup', 'U6861179', 'NOK']
# ['AccountOrGroup', 'U6861179', 'NZD']
# ['AccountOrGroup', 'U6861179', 'NZD']
# ['AccountOrGroup', 'U6861179', 'PLN']
# ['AccountOrGroup', 'U6861179', 'PLN']
# ['AccountOrGroup', 'U6861179', 'SEK']
# ['AccountOrGroup', 'U6861179', 'SEK']
# ['AccountOrGroup', 'U6861179', 'SGD']
# ['AccountOrGroup', 'U6861179', 'SGD']
# ['AccountOrGroup', 'U6861179', 'TRY']
# ['AccountOrGroup', 'U6861179', 'TRY']
# ['AccountOrGroup', 'U6861179', 'USD']
# ['AccountOrGroup', 'U6861179', 'USD']
# ['AccountOrGroup', 'U6861179', 'ZAR']
# ['AccountOrGroup', 'U6861179', 'ZAR']
# ['AccountReady', 'true', '']
# ['AccountReady', 'true', '']
# ['AccountType', 'INDIVIDUAL', '']
# ['AccountType', 'INDIVIDUAL', '']
# ['AccruedCash', '-58.49', 'AUD']
# ['AccruedCash', '-58.49', 'AUD']
# ['AccruedCash', '8328.497585', 'BASE']
# ['AccruedCash', '8328.497585', 'BASE']
# ['AccruedCash', '-234.96', 'CAD']
# ['AccruedCash', '-234.96', 'CAD']
# ['AccruedCash', '-1.53', 'CHF']
# ['AccruedCash', '-1.53', 'CHF']
# ['AccruedCash', '0.00', 'CNH']
# ['AccruedCash', '0.00', 'CNH']
# ['AccruedCash', '0.00', 'CZK']
# ['AccruedCash', '0.00', 'CZK']
# ['AccruedCash', '0.00', 'EUR']
# ['AccruedCash', '0.00', 'EUR']
# ['AccruedCash', '103.04', 'GBP']
# ['AccruedCash', '103.04', 'GBP']
# ['AccruedCash', '8328.50', 'HKD']
# ['AccruedCash', '8328.50', 'HKD']
# ['AccruedCash', '-604.83', 'HUF']
# ['AccruedCash', '-604.83', 'HUF']
# ['AccruedCash', '0.00', 'ILS']
# ['AccruedCash', '0.00', 'ILS']
# ['AccruedCash', '-6266.00', 'JPY']
# ['AccruedCash', '-6266.00', 'JPY']
# ['AccruedCash', '0.00', 'KRW']
# ['AccruedCash', '0.00', 'KRW']
# ['AccruedCash', '0.00', 'NOK']
# ['AccruedCash', '0.00', 'NOK']
# ['AccruedCash', '0.00', 'NZD']
# ['AccruedCash', '0.00', 'NZD']
# ['AccruedCash', '0.00', 'PLN']
# ['AccruedCash', '0.00', 'PLN']
# ['AccruedCash', '0.00', 'SEK']
# ['AccruedCash', '0.00', 'SEK']
# ['AccruedCash', '0.00', 'SGD']
# ['AccruedCash', '0.00', 'SGD']
# ['AccruedCash', '0.00', 'TRY']
# ['AccruedCash', '0.00', 'TRY']
# ['AccruedCash', '1200.14', 'USD']
# ['AccruedCash', '1200.14', 'USD']
# ['AccruedCash', '-218.75', 'ZAR']
# ['AccruedCash', '-218.75', 'ZAR']
# ['AccruedCash-S', '8328.50', 'HKD']
# ['AccruedCash-S', '8328.50', 'HKD']
# ['AccruedDividend', '0.00', 'HKD']
# ['AccruedDividend', '0.00', 'HKD']
# ['AccruedDividend-S', '0.00', 'HKD']
# ['AccruedDividend-S', '0.00', 'HKD']
# ['AvailableFunds', '2315166.50', 'HKD']
# ['AvailableFunds', '2315166.50', 'HKD']
# ['AvailableFunds-S', '2315166.50', 'HKD']
# ['AvailableFunds-S', '2315166.50', 'HKD']
# ['Billable', '0.00', 'HKD']
# ['Billable', '0.00', 'HKD']
# ['Billable-S', '0.00', 'HKD']
# ['Billable-S', '0.00', 'HKD']
# ['BuyingPower', '15434443.30', 'HKD']
# ['BuyingPower', '15434443.30', 'HKD']
# ['CashBalance', '695244.24', 'AUD']
# ['CashBalance', '695244.24', 'AUD']
# ['CashBalance', '2678673.6881', 'BASE']
# ['CashBalance', '2678673.6881', 'BASE']
# ['CashBalance', '682342.92', 'CAD']
# ['CashBalance', '682342.92', 'CAD']
# ['CashBalance', '190.16', 'CHF']
# ['CashBalance', '190.16', 'CHF']
# ['CashBalance', '853.35', 'CNH']
# ['CashBalance', '853.35', 'CNH']
# ['CashBalance', '2372.78', 'CZK']
# ['CashBalance', '2372.78', 'CZK']
# ['CashBalance', '895.20', 'EUR']
# ['CashBalance', '895.20', 'EUR']
# ['CashBalance', '-749384.75', 'GBP']
# ['CashBalance', '-749384.75', 'GBP']
# ['CashBalance', '-13.36', 'HKD']
# ['CashBalance', '-13.36', 'HKD']
# ['CashBalance', '6412.76', 'HUF']
# ['CashBalance', '6412.76', 'HUF']
# ['CashBalance', '555.98', 'ILS']
# ['CashBalance', '555.98', 'ILS']
# ['CashBalance', '164827.15', 'JPY']
# ['CashBalance', '164827.15', 'JPY']
# ['CashBalance', '22448.99', 'KRW']
# ['CashBalance', '22448.99', 'KRW']
# ['CashBalance', '555.39', 'NOK']
# ['CashBalance', '555.39', 'NOK']
# ['CashBalance', '355.50', 'NZD']
# ['CashBalance', '355.50', 'NZD']
# ['CashBalance', '2683.39', 'PLN']
# ['CashBalance', '2683.39', 'PLN']
# ['CashBalance', '2307.45', 'SEK']
# ['CashBalance', '2307.45', 'SEK']
# ['CashBalance', '185.26', 'SGD']
# ['CashBalance', '185.26', 'SGD']
# ['CashBalance', '30638.18', 'TRY']
# ['CashBalance', '30638.18', 'TRY']
# ['CashBalance', '334022.06', 'USD']
# ['CashBalance', '334022.06', 'USD']
# ['CashBalance', '-34153.66', 'ZAR']
# ['CashBalance', '-34153.66', 'ZAR']
# ['ColumnPrio-S', '1', '']
# ['ColumnPrio-S', '1', '']
# ['CorporateBondValue', '0.00', 'AUD']
# ['CorporateBondValue', '0.00', 'AUD']
# ['CorporateBondValue', '0.00', 'BASE']
# ['CorporateBondValue', '0.00', 'BASE']
# ['CorporateBondValue', '0.00', 'CAD']
# ['CorporateBondValue', '0.00', 'CAD']
# ['CorporateBondValue', '0.00', 'CHF']
# ['CorporateBondValue', '0.00', 'CHF']
# ['CorporateBondValue', '0.00', 'CNH']
# ['CorporateBondValue', '0.00', 'CNH']
# ['CorporateBondValue', '0.00', 'CZK']
# ['CorporateBondValue', '0.00', 'CZK']
# ['CorporateBondValue', '0.00', 'EUR']
# ['CorporateBondValue', '0.00', 'EUR']
# ['CorporateBondValue', '0.00', 'GBP']
# ['CorporateBondValue', '0.00', 'GBP']
# ['CorporateBondValue', '0.00', 'HKD']
# ['CorporateBondValue', '0.00', 'HKD']
# ['CorporateBondValue', '0.00', 'HUF']
# ['CorporateBondValue', '0.00', 'HUF']
# ['CorporateBondValue', '0.00', 'ILS']
# ['CorporateBondValue', '0.00', 'ILS']
# ['CorporateBondValue', '0.00', 'JPY']
# ['CorporateBondValue', '0.00', 'JPY']
# ['CorporateBondValue', '0.00', 'KRW']
# ['CorporateBondValue', '0.00', 'KRW']
# ['CorporateBondValue', '0.00', 'NOK']
# ['CorporateBondValue', '0.00', 'NOK']
# ['CorporateBondValue', '0.00', 'NZD']
# ['CorporateBondValue', '0.00', 'NZD']
# ['CorporateBondValue', '0.00', 'PLN']
# ['CorporateBondValue', '0.00', 'PLN']
# ['CorporateBondValue', '0.00', 'SEK']
# ['CorporateBondValue', '0.00', 'SEK']
# ['CorporateBondValue', '0.00', 'SGD']
# ['CorporateBondValue', '0.00', 'SGD']
# ['CorporateBondValue', '0.00', 'TRY']
# ['CorporateBondValue', '0.00', 'TRY']
# ['CorporateBondValue', '0.00', 'USD']
# ['CorporateBondValue', '0.00', 'USD']
# ['CorporateBondValue', '0.00', 'ZAR']
# ['CorporateBondValue', '0.00', 'ZAR']
# ['Cryptocurrency', '0.00', 'AUD']
# ['Cryptocurrency', '0.00', 'AUD']
# ['Cryptocurrency', '0.00', 'BASE']
# ['Cryptocurrency', '0.00', 'BASE']
# ['Cryptocurrency', '0.00', 'CAD']
# ['Cryptocurrency', '0.00', 'CAD']
# ['Cryptocurrency', '0.00', 'CHF']
# ['Cryptocurrency', '0.00', 'CHF']
# ['Cryptocurrency', '0.00', 'CNH']
# ['Cryptocurrency', '0.00', 'CNH']
# ['Cryptocurrency', '0.00', 'CZK']
# ['Cryptocurrency', '0.00', 'CZK']
# ['Cryptocurrency', '0.00', 'EUR']
# ['Cryptocurrency', '0.00', 'EUR']
# ['Cryptocurrency', '0.00', 'GBP']
# ['Cryptocurrency', '0.00', 'GBP']
# ['Cryptocurrency', '0.00', 'HKD']
# ['Cryptocurrency', '0.00', 'HKD']
# ['Cryptocurrency', '0.00', 'HUF']
# ['Cryptocurrency', '0.00', 'HUF']
# ['Cryptocurrency', '0.00', 'ILS']
# ['Cryptocurrency', '0.00', 'ILS']
# ['Cryptocurrency', '0.00', 'JPY']
# ['Cryptocurrency', '0.00', 'JPY']
# ['Cryptocurrency', '0.00', 'KRW']
# ['Cryptocurrency', '0.00', 'KRW']
# ['Cryptocurrency', '0.00', 'NOK']
# ['Cryptocurrency', '0.00', 'NOK']
# ['Cryptocurrency', '0.00', 'NZD']
# ['Cryptocurrency', '0.00', 'NZD']
# ['Cryptocurrency', '0.00', 'PLN']
# ['Cryptocurrency', '0.00', 'PLN']
# ['Cryptocurrency', '0.00', 'SEK']
# ['Cryptocurrency', '0.00', 'SEK']
# ['Cryptocurrency', '0.00', 'SGD']
# ['Cryptocurrency', '0.00', 'SGD']
# ['Cryptocurrency', '0.00', 'TRY']
# ['Cryptocurrency', '0.00', 'TRY']
# ['Cryptocurrency', '0.00', 'USD']
# ['Cryptocurrency', '0.00', 'USD']
# ['Cryptocurrency', '0.00', 'ZAR']
# ['Cryptocurrency', '0.00', 'ZAR']
# ['Currency', 'AUD', 'AUD']
# ['Currency', 'AUD', 'AUD']
# ['Currency', 'BASE', 'BASE']
# ['Currency', 'BASE', 'BASE']
# ['Currency', 'CAD', 'CAD']
# ['Currency', 'CAD', 'CAD']
# ['Currency', 'CHF', 'CHF']
# ['Currency', 'CHF', 'CHF']
# ['Currency', 'CNH', 'CNH']
# ['Currency', 'CNH', 'CNH']
# ['Currency', 'CZK', 'CZK']
# ['Currency', 'CZK', 'CZK']
# ['Currency', 'EUR', 'EUR']
# ['Currency', 'EUR', 'EUR']
# ['Currency', 'GBP', 'GBP']
# ['Currency', 'GBP', 'GBP']
# ['Currency', 'HKD', 'HKD']
# ['Currency', 'HKD', 'HKD']
# ['Currency', 'HUF', 'HUF']
# ['Currency', 'HUF', 'HUF']
# ['Currency', 'ILS', 'ILS']
# ['Currency', 'ILS', 'ILS']
# ['Currency', 'JPY', 'JPY']
# ['Currency', 'JPY', 'JPY']
# ['Currency', 'KRW', 'KRW']
# ['Currency', 'KRW', 'KRW']
# ['Currency', 'NOK', 'NOK']
# ['Currency', 'NOK', 'NOK']
# ['Currency', 'NZD', 'NZD']
# ['Currency', 'NZD', 'NZD']
# ['Currency', 'PLN', 'PLN']
# ['Currency', 'PLN', 'PLN']
# ['Currency', 'SEK', 'SEK']
# ['Currency', 'SEK', 'SEK']
# ['Currency', 'SGD', 'SGD']
# ['Currency', 'SGD', 'SGD']
# ['Currency', 'TRY', 'TRY']
# ['Currency', 'TRY', 'TRY']
# ['Currency', 'USD', 'USD']
# ['Currency', 'USD', 'USD']
# ['Currency', 'ZAR', 'ZAR']
# ['Currency', 'ZAR', 'ZAR']
# ['Cushion', '0.912058', '']
# ['Cushion', '0.912058', '']
# ['EquityWithLoanValue', '2687002.19', 'HKD']
# ['EquityWithLoanValue', '2687002.19', 'HKD']
# ['EquityWithLoanValue-S', '2687002.19', 'HKD']
# ['EquityWithLoanValue-S', '2687002.19', 'HKD']
# ['ExcessLiquidity', '2450701.74', 'HKD']
# ['ExcessLiquidity', '2450701.74', 'HKD']
# ['ExcessLiquidity-S', '2450701.74', 'HKD']
# ['ExcessLiquidity-S', '2450701.74', 'HKD']
# ['ExchangeRate', '5.0448334', 'AUD']
# ['ExchangeRate', '5.0448334', 'AUD']
# ['ExchangeRate', '1.00', 'BASE']
# ['ExchangeRate', '1.00', 'BASE']
# ['ExchangeRate', '5.7711195', 'CAD']
# ['ExchangeRate', '5.7711195', 'CAD']
# ['ExchangeRate', '8.8823781', 'CHF']
# ['ExchangeRate', '8.8823781', 'CHF']
# ['ExchangeRate', '1.0764608', 'CNH']
# ['ExchangeRate', '1.0764608', 'CNH']
# ['ExchangeRate', '0.352064', 'CZK']
# ['ExchangeRate', '0.352064', 'CZK']
# ['ExchangeRate', '8.4802224', 'EUR']
# ['ExchangeRate', '8.4802224', 'EUR']
# ['ExchangeRate', '9.8855207', 'GBP']
# ['ExchangeRate', '9.8855207', 'GBP']
# ['ExchangeRate', '1.00', 'HKD']
# ['ExchangeRate', '1.00', 'HKD']
# ['ExchangeRate', '0.0222149', 'HUF']
# ['ExchangeRate', '0.0222149', 'HUF']
# ['ExchangeRate', '2.0679497', 'ILS']
# ['ExchangeRate', '2.0679497', 'ILS']
# ['ExchangeRate', '0.0535526', 'JPY']
# ['ExchangeRate', '0.0535526', 'JPY']
# ['ExchangeRate', '0.005922', 'KRW']
# ['ExchangeRate', '0.005922', 'KRW']
# ['ExchangeRate', '0.7343531', 'NOK']
# ['ExchangeRate', '0.7343531', 'NOK']
# ['ExchangeRate', '4.6424234', 'NZD']
# ['ExchangeRate', '4.6424234', 'NZD']
# ['ExchangeRate', '1.897072', 'PLN']
# ['ExchangeRate', '1.897072', 'PLN']
# ['ExchangeRate', '0.7112144', 'SEK']
# ['ExchangeRate', '0.7112144', 'SEK']
# ['ExchangeRate', '5.7855922', 'SGD']
# ['ExchangeRate', '5.7855922', 'SGD']
# ['ExchangeRate', '0.2961723', 'TRY']
# ['ExchangeRate', '0.2961723', 'TRY']
# ['ExchangeRate', '7.8442502', 'USD']
# ['ExchangeRate', '7.8442502', 'USD']
# ['ExchangeRate', '0.4216914', 'ZAR']
# ['ExchangeRate', '0.4216914', 'ZAR']
# ['FullAvailableFunds', '2315166.50', 'HKD']
# ['FullAvailableFunds', '2315166.50', 'HKD']
# ['FullAvailableFunds-S', '2315166.50', 'HKD']
# ['FullAvailableFunds-S', '2315166.50', 'HKD']
# ['FullExcessLiquidity', '2450701.74', 'HKD']
# ['FullExcessLiquidity', '2450701.74', 'HKD']
# ['FullExcessLiquidity-S', '2450701.74', 'HKD']
# ['FullExcessLiquidity-S', '2450701.74', 'HKD']
# ['FullInitMarginReq', '371835.69', 'HKD']
# ['FullInitMarginReq', '371835.69', 'HKD']
# ['FullInitMarginReq-S', '371835.69', 'HKD']
# ['FullInitMarginReq-S', '371835.69', 'HKD']
# ['FullMaintMarginReq', '236300.44', 'HKD']
# ['FullMaintMarginReq', '236300.44', 'HKD']
# ['FullMaintMarginReq-S', '236300.44', 'HKD']
# ['FullMaintMarginReq-S', '236300.44', 'HKD']
# ['FundValue', '0.00', 'AUD']
# ['FundValue', '0.00', 'AUD']
# ['FundValue', '0.00', 'BASE']
# ['FundValue', '0.00', 'BASE']
# ['FundValue', '0.00', 'CAD']
# ['FundValue', '0.00', 'CAD']
# ['FundValue', '0.00', 'CHF']
# ['FundValue', '0.00', 'CHF']
# ['FundValue', '0.00', 'CNH']
# ['FundValue', '0.00', 'CNH']
# ['FundValue', '0.00', 'CZK']
# ['FundValue', '0.00', 'CZK']
# ['FundValue', '0.00', 'EUR']
# ['FundValue', '0.00', 'EUR']
# ['FundValue', '0.00', 'GBP']
# ['FundValue', '0.00', 'GBP']
# ['FundValue', '0.00', 'HKD']
# ['FundValue', '0.00', 'HKD']
# ['FundValue', '0.00', 'HUF']
# ['FundValue', '0.00', 'HUF']
# ['FundValue', '0.00', 'ILS']
# ['FundValue', '0.00', 'ILS']
# ['FundValue', '0.00', 'JPY']
# ['FundValue', '0.00', 'JPY']
# ['FundValue', '0.00', 'KRW']
# ['FundValue', '0.00', 'KRW']
# ['FundValue', '0.00', 'NOK']
# ['FundValue', '0.00', 'NOK']
# ['FundValue', '0.00', 'NZD']
# ['FundValue', '0.00', 'NZD']
# ['FundValue', '0.00', 'PLN']
# ['FundValue', '0.00', 'PLN']
# ['FundValue', '0.00', 'SEK']
# ['FundValue', '0.00', 'SEK']
# ['FundValue', '0.00', 'SGD']
# ['FundValue', '0.00', 'SGD']
# ['FundValue', '0.00', 'TRY']
# ['FundValue', '0.00', 'TRY']
# ['FundValue', '0.00', 'USD']
# ['FundValue', '0.00', 'USD']
# ['FundValue', '0.00', 'ZAR']
# ['FundValue', '0.00', 'ZAR']
# ['FutureOptionValue', '0.00', 'AUD']
# ['FutureOptionValue', '0.00', 'AUD']
# ['FutureOptionValue', '0.00', 'BASE']
# ['FutureOptionValue', '0.00', 'BASE']
# ['FutureOptionValue', '0.00', 'CAD']
# ['FutureOptionValue', '0.00', 'CAD']
# ['FutureOptionValue', '0.00', 'CHF']
# ['FutureOptionValue', '0.00', 'CHF']
# ['FutureOptionValue', '0.00', 'CNH']
# ['FutureOptionValue', '0.00', 'CNH']
# ['FutureOptionValue', '0.00', 'CZK']
# ['FutureOptionValue', '0.00', 'CZK']
# ['FutureOptionValue', '0.00', 'EUR']
# ['FutureOptionValue', '0.00', 'EUR']
# ['FutureOptionValue', '0.00', 'GBP']
# ['FutureOptionValue', '0.00', 'GBP']
# ['FutureOptionValue', '0.00', 'HKD']
# ['FutureOptionValue', '0.00', 'HKD']
# ['FutureOptionValue', '0.00', 'HUF']
# ['FutureOptionValue', '0.00', 'HUF']
# ['FutureOptionValue', '0.00', 'ILS']
# ['FutureOptionValue', '0.00', 'ILS']
# ['FutureOptionValue', '0.00', 'JPY']
# ['FutureOptionValue', '0.00', 'JPY']
# ['FutureOptionValue', '0.00', 'KRW']
# ['FutureOptionValue', '0.00', 'KRW']
# ['FutureOptionValue', '0.00', 'NOK']
# ['FutureOptionValue', '0.00', 'NOK']
# ['FutureOptionValue', '0.00', 'NZD']
# ['FutureOptionValue', '0.00', 'NZD']
# ['FutureOptionValue', '0.00', 'PLN']
# ['FutureOptionValue', '0.00', 'PLN']
# ['FutureOptionValue', '0.00', 'SEK']
# ['FutureOptionValue', '0.00', 'SEK']
# ['FutureOptionValue', '0.00', 'SGD']
# ['FutureOptionValue', '0.00', 'SGD']
# ['FutureOptionValue', '0.00', 'TRY']
# ['FutureOptionValue', '0.00', 'TRY']
# ['FutureOptionValue', '0.00', 'USD']
# ['FutureOptionValue', '0.00', 'USD']
# ['FutureOptionValue', '0.00', 'ZAR']
# ['FutureOptionValue', '0.00', 'ZAR']
# ['FuturesPNL', '0.00', 'AUD']
# ['FuturesPNL', '0.00', 'AUD']
# ['FuturesPNL', '0.00', 'BASE']
# ['FuturesPNL', '0.00', 'BASE']
# ['FuturesPNL', '0.00', 'CAD']
# ['FuturesPNL', '0.00', 'CAD']
# ['FuturesPNL', '0.00', 'CHF']
# ['FuturesPNL', '0.00', 'CHF']
# ['FuturesPNL', '0.00', 'CNH']
# ['FuturesPNL', '0.00', 'CNH']
# ['FuturesPNL', '0.00', 'CZK']
# ['FuturesPNL', '0.00', 'CZK']
# ['FuturesPNL', '0.00', 'EUR']
# ['FuturesPNL', '0.00', 'EUR']
# ['FuturesPNL', '0.00', 'GBP']
# ['FuturesPNL', '0.00', 'GBP']
# ['FuturesPNL', '0.00', 'HKD']
# ['FuturesPNL', '0.00', 'HKD']
# ['FuturesPNL', '0.00', 'HUF']
# ['FuturesPNL', '0.00', 'HUF']
# ['FuturesPNL', '0.00', 'ILS']
# ['FuturesPNL', '0.00', 'ILS']
# ['FuturesPNL', '0.00', 'JPY']
# ['FuturesPNL', '0.00', 'JPY']
# ['FuturesPNL', '0.00', 'KRW']
# ['FuturesPNL', '0.00', 'KRW']
# ['FuturesPNL', '0.00', 'NOK']
# ['FuturesPNL', '0.00', 'NOK']
# ['FuturesPNL', '0.00', 'NZD']
# ['FuturesPNL', '0.00', 'NZD']
# ['FuturesPNL', '0.00', 'PLN']
# ['FuturesPNL', '0.00', 'PLN']
# ['FuturesPNL', '0.00', 'SEK']
# ['FuturesPNL', '0.00', 'SEK']
# ['FuturesPNL', '0.00', 'SGD']
# ['FuturesPNL', '0.00', 'SGD']
# ['FuturesPNL', '0.00', 'TRY']
# ['FuturesPNL', '0.00', 'TRY']
# ['FuturesPNL', '0.00', 'USD']
# ['FuturesPNL', '0.00', 'USD']
# ['FuturesPNL', '0.00', 'ZAR']
# ['FuturesPNL', '0.00', 'ZAR']
# ['FxCashBalance', '0.00', 'AUD']
# ['FxCashBalance', '0.00', 'AUD']
# ['FxCashBalance', '0.00', 'BASE']
# ['FxCashBalance', '0.00', 'BASE']
# ['FxCashBalance', '0.00', 'CAD']
# ['FxCashBalance', '0.00', 'CAD']
# ['FxCashBalance', '0.00', 'CHF']
# ['FxCashBalance', '0.00', 'CHF']
# ['FxCashBalance', '0.00', 'CNH']
# ['FxCashBalance', '0.00', 'CNH']
# ['FxCashBalance', '0.00', 'CZK']
# ['FxCashBalance', '0.00', 'CZK']
# ['FxCashBalance', '0.00', 'EUR']
# ['FxCashBalance', '0.00', 'EUR']
# ['FxCashBalance', '0.00', 'GBP']
# ['FxCashBalance', '0.00', 'GBP']
# ['FxCashBalance', '0.00', 'HKD']
# ['FxCashBalance', '0.00', 'HKD']
# ['FxCashBalance', '0.00', 'HUF']
# ['FxCashBalance', '0.00', 'HUF']
# ['FxCashBalance', '0.00', 'ILS']
# ['FxCashBalance', '0.00', 'ILS']
# ['FxCashBalance', '0.00', 'JPY']
# ['FxCashBalance', '0.00', 'JPY']
# ['FxCashBalance', '0.00', 'KRW']
# ['FxCashBalance', '0.00', 'KRW']
# ['FxCashBalance', '0.00', 'NOK']
# ['FxCashBalance', '0.00', 'NOK']
# ['FxCashBalance', '0.00', 'NZD']
# ['FxCashBalance', '0.00', 'NZD']
# ['FxCashBalance', '0.00', 'PLN']
# ['FxCashBalance', '0.00', 'PLN']
# ['FxCashBalance', '0.00', 'SEK']
# ['FxCashBalance', '0.00', 'SEK']
# ['FxCashBalance', '0.00', 'SGD']
# ['FxCashBalance', '0.00', 'SGD']
# ['FxCashBalance', '0.00', 'TRY']
# ['FxCashBalance', '0.00', 'TRY']
# ['FxCashBalance', '0.00', 'USD']
# ['FxCashBalance', '0.00', 'USD']
# ['FxCashBalance', '0.00', 'ZAR']
# ['FxCashBalance', '0.00', 'ZAR']
# ['GrossPositionValue', '0.00', 'HKD']
# ['GrossPositionValue', '0.00', 'HKD']
# ['GrossPositionValue-S', '0.00', 'HKD']
# ['GrossPositionValue-S', '0.00', 'HKD']
# ['Guarantee', '0.00', 'HKD']
# ['Guarantee', '0.00', 'HKD']
# ['Guarantee-S', '0.00', 'HKD']
# ['Guarantee-S', '0.00', 'HKD']
# ['IndianStockHaircut', '0.00', 'HKD']
# ['IndianStockHaircut', '0.00', 'HKD']
# ['IndianStockHaircut-S', '0.00', 'HKD']
# ['IndianStockHaircut-S', '0.00', 'HKD']
# ['InitMarginReq', '371835.69', 'HKD']
# ['InitMarginReq', '371835.69', 'HKD']
# ['InitMarginReq-S', '371835.69', 'HKD']
# ['InitMarginReq-S', '371835.69', 'HKD']
# ['IssuerOptionValue', '0.00', 'AUD']
# ['IssuerOptionValue', '0.00', 'AUD']
# ['IssuerOptionValue', '0.00', 'BASE']
# ['IssuerOptionValue', '0.00', 'BASE']
# ['IssuerOptionValue', '0.00', 'CAD']
# ['IssuerOptionValue', '0.00', 'CAD']
# ['IssuerOptionValue', '0.00', 'CHF']
# ['IssuerOptionValue', '0.00', 'CHF']
# ['IssuerOptionValue', '0.00', 'CNH']
# ['IssuerOptionValue', '0.00', 'CNH']
# ['IssuerOptionValue', '0.00', 'CZK']
# ['IssuerOptionValue', '0.00', 'CZK']
# ['IssuerOptionValue', '0.00', 'EUR']
# ['IssuerOptionValue', '0.00', 'EUR']
# ['IssuerOptionValue', '0.00', 'GBP']
# ['IssuerOptionValue', '0.00', 'GBP']
# ['IssuerOptionValue', '0.00', 'HKD']
# ['IssuerOptionValue', '0.00', 'HKD']
# ['IssuerOptionValue', '0.00', 'HUF']
# ['IssuerOptionValue', '0.00', 'HUF']
# ['IssuerOptionValue', '0.00', 'ILS']
# ['IssuerOptionValue', '0.00', 'ILS']
# ['IssuerOptionValue', '0.00', 'JPY']
# ['IssuerOptionValue', '0.00', 'JPY']
# ['IssuerOptionValue', '0.00', 'KRW']
# ['IssuerOptionValue', '0.00', 'KRW']
# ['IssuerOptionValue', '0.00', 'NOK']
# ['IssuerOptionValue', '0.00', 'NOK']
# ['IssuerOptionValue', '0.00', 'NZD']
# ['IssuerOptionValue', '0.00', 'NZD']
# ['IssuerOptionValue', '0.00', 'PLN']
# ['IssuerOptionValue', '0.00', 'PLN']
# ['IssuerOptionValue', '0.00', 'SEK']
# ['IssuerOptionValue', '0.00', 'SEK']
# ['IssuerOptionValue', '0.00', 'SGD']
# ['IssuerOptionValue', '0.00', 'SGD']
# ['IssuerOptionValue', '0.00', 'TRY']
# ['IssuerOptionValue', '0.00', 'TRY']
# ['IssuerOptionValue', '0.00', 'USD']
# ['IssuerOptionValue', '0.00', 'USD']
# ['IssuerOptionValue', '0.00', 'ZAR']
# ['IssuerOptionValue', '0.00', 'ZAR']
# ['Leverage-S', '0.00', '']
# ['Leverage-S', '0.00', '']
# ['LookAheadAvailableFunds', '2315166.50', 'HKD']
# ['LookAheadAvailableFunds', '2315166.50', 'HKD']
# ['LookAheadAvailableFunds-S', '2315166.50', 'HKD']
# ['LookAheadAvailableFunds-S', '2315166.50', 'HKD']
# ['LookAheadExcessLiquidity', '2450701.74', 'HKD']
# ['LookAheadExcessLiquidity', '2450701.74', 'HKD']
# ['LookAheadExcessLiquidity-S', '2450701.74', 'HKD']
# ['LookAheadExcessLiquidity-S', '2450701.74', 'HKD']
# ['LookAheadInitMarginReq', '371835.69', 'HKD']
# ['LookAheadInitMarginReq', '371835.69', 'HKD']
# ['LookAheadInitMarginReq-S', '371835.69', 'HKD']
# ['LookAheadInitMarginReq-S', '371835.69', 'HKD']
# ['LookAheadMaintMarginReq', '236300.44', 'HKD']
# ['LookAheadMaintMarginReq', '236300.44', 'HKD']
# ['LookAheadMaintMarginReq-S', '236300.44', 'HKD']
# ['LookAheadMaintMarginReq-S', '236300.44', 'HKD']
# ['LookAheadNextChange', '0', '']
# ['LookAheadNextChange', '0', '']
# ['MaintMarginReq', '236300.44', 'HKD']
# ['MaintMarginReq', '236300.44', 'HKD']
# ['MaintMarginReq-S', '236300.44', 'HKD']
# ['MaintMarginReq-S', '236300.44', 'HKD']
# ['MoneyMarketFundValue', '0.00', 'AUD']
# ['MoneyMarketFundValue', '0.00', 'AUD']
# ['MoneyMarketFundValue', '0.00', 'BASE']
# ['MoneyMarketFundValue', '0.00', 'BASE']
# ['MoneyMarketFundValue', '0.00', 'CAD']
# ['MoneyMarketFundValue', '0.00', 'CAD']
# ['MoneyMarketFundValue', '0.00', 'CHF']
# ['MoneyMarketFundValue', '0.00', 'CHF']
# ['MoneyMarketFundValue', '0.00', 'CNH']
# ['MoneyMarketFundValue', '0.00', 'CNH']
# ['MoneyMarketFundValue', '0.00', 'CZK']
# ['MoneyMarketFundValue', '0.00', 'CZK']
# ['MoneyMarketFundValue', '0.00', 'EUR']
# ['MoneyMarketFundValue', '0.00', 'EUR']
# ['MoneyMarketFundValue', '0.00', 'GBP']
# ['MoneyMarketFundValue', '0.00', 'GBP']
# ['MoneyMarketFundValue', '0.00', 'HKD']
# ['MoneyMarketFundValue', '0.00', 'HKD']
# ['MoneyMarketFundValue', '0.00', 'HUF']
# ['MoneyMarketFundValue', '0.00', 'HUF']
# ['MoneyMarketFundValue', '0.00', 'ILS']
# ['MoneyMarketFundValue', '0.00', 'ILS']
# ['MoneyMarketFundValue', '0.00', 'JPY']
# ['MoneyMarketFundValue', '0.00', 'JPY']
# ['MoneyMarketFundValue', '0.00', 'KRW']
# ['MoneyMarketFundValue', '0.00', 'KRW']
# ['MoneyMarketFundValue', '0.00', 'NOK']
# ['MoneyMarketFundValue', '0.00', 'NOK']
# ['MoneyMarketFundValue', '0.00', 'NZD']
# ['MoneyMarketFundValue', '0.00', 'NZD']
# ['MoneyMarketFundValue', '0.00', 'PLN']
# ['MoneyMarketFundValue', '0.00', 'PLN']
# ['MoneyMarketFundValue', '0.00', 'SEK']
# ['MoneyMarketFundValue', '0.00', 'SEK']
# ['MoneyMarketFundValue', '0.00', 'SGD']
# ['MoneyMarketFundValue', '0.00', 'SGD']
# ['MoneyMarketFundValue', '0.00', 'TRY']
# ['MoneyMarketFundValue', '0.00', 'TRY']
# ['MoneyMarketFundValue', '0.00', 'USD']
# ['MoneyMarketFundValue', '0.00', 'USD']
# ['MoneyMarketFundValue', '0.00', 'ZAR']
# ['MoneyMarketFundValue', '0.00', 'ZAR']
# ['MutualFundValue', '0.00', 'AUD']
# ['MutualFundValue', '0.00', 'AUD']
# ['MutualFundValue', '0.00', 'BASE']
# ['MutualFundValue', '0.00', 'BASE']
# ['MutualFundValue', '0.00', 'CAD']
# ['MutualFundValue', '0.00', 'CAD']
# ['MutualFundValue', '0.00', 'CHF']
# ['MutualFundValue', '0.00', 'CHF']
# ['MutualFundValue', '0.00', 'CNH']
# ['MutualFundValue', '0.00', 'CNH']
# ['MutualFundValue', '0.00', 'CZK']
# ['MutualFundValue', '0.00', 'CZK']
# ['MutualFundValue', '0.00', 'EUR']
# ['MutualFundValue', '0.00', 'EUR']
# ['MutualFundValue', '0.00', 'GBP']
# ['MutualFundValue', '0.00', 'GBP']
# ['MutualFundValue', '0.00', 'HKD']
# ['MutualFundValue', '0.00', 'HKD']
# ['MutualFundValue', '0.00', 'HUF']
# ['MutualFundValue', '0.00', 'HUF']
# ['MutualFundValue', '0.00', 'ILS']
# ['MutualFundValue', '0.00', 'ILS']
# ['MutualFundValue', '0.00', 'JPY']
# ['MutualFundValue', '0.00', 'JPY']
# ['MutualFundValue', '0.00', 'KRW']
# ['MutualFundValue', '0.00', 'KRW']
# ['MutualFundValue', '0.00', 'NOK']
# ['MutualFundValue', '0.00', 'NOK']
# ['MutualFundValue', '0.00', 'NZD']
# ['MutualFundValue', '0.00', 'NZD']
# ['MutualFundValue', '0.00', 'PLN']
# ['MutualFundValue', '0.00', 'PLN']
# ['MutualFundValue', '0.00', 'SEK']
# ['MutualFundValue', '0.00', 'SEK']
# ['MutualFundValue', '0.00', 'SGD']
# ['MutualFundValue', '0.00', 'SGD']
# ['MutualFundValue', '0.00', 'TRY']
# ['MutualFundValue', '0.00', 'TRY']
# ['MutualFundValue', '0.00', 'USD']
# ['MutualFundValue', '0.00', 'USD']
# ['MutualFundValue', '0.00', 'ZAR']
# ['MutualFundValue', '0.00', 'ZAR']
# ['NLVAndMarginInReview', 'false', '']
# ['NLVAndMarginInReview', 'false', '']
# ['NetDividend', '0.00', 'AUD']
# ['NetDividend', '0.00', 'AUD']
# ['NetDividend', '0.00', 'BASE']
# ['NetDividend', '0.00', 'BASE']
# ['NetDividend', '0.00', 'CAD']
# ['NetDividend', '0.00', 'CAD']
# ['NetDividend', '0.00', 'CHF']
# ['NetDividend', '0.00', 'CHF']
# ['NetDividend', '0.00', 'CNH']
# ['NetDividend', '0.00', 'CNH']
# ['NetDividend', '0.00', 'CZK']
# ['NetDividend', '0.00', 'CZK']
# ['NetDividend', '0.00', 'EUR']
# ['NetDividend', '0.00', 'EUR']
# ['NetDividend', '0.00', 'GBP']
# ['NetDividend', '0.00', 'GBP']
# ['NetDividend', '0.00', 'HKD']
# ['NetDividend', '0.00', 'HKD']
# ['NetDividend', '0.00', 'HUF']
# ['NetDividend', '0.00', 'HUF']
# ['NetDividend', '0.00', 'ILS']
# ['NetDividend', '0.00', 'ILS']
# ['NetDividend', '0.00', 'JPY']
# ['NetDividend', '0.00', 'JPY']
# ['NetDividend', '0.00', 'KRW']
# ['NetDividend', '0.00', 'KRW']
# ['NetDividend', '0.00', 'NOK']
# ['NetDividend', '0.00', 'NOK']
# ['NetDividend', '0.00', 'NZD']
# ['NetDividend', '0.00', 'NZD']
# ['NetDividend', '0.00', 'PLN']
# ['NetDividend', '0.00', 'PLN']
# ['NetDividend', '0.00', 'SEK']
# ['NetDividend', '0.00', 'SEK']
# ['NetDividend', '0.00', 'SGD']
# ['NetDividend', '0.00', 'SGD']
# ['NetDividend', '0.00', 'TRY']
# ['NetDividend', '0.00', 'TRY']
# ['NetDividend', '0.00', 'USD']
# ['NetDividend', '0.00', 'USD']
# ['NetDividend', '0.00', 'ZAR']
# ['NetDividend', '0.00', 'ZAR']
# ['NetLiquidation', '2687002.19', 'HKD']
# ['NetLiquidation', '2687002.19', 'HKD']
# ['NetLiquidation-S', '2687002.19', 'HKD']
# ['NetLiquidation-S', '2687002.19', 'HKD']
# ['NetLiquidationByCurrency', '695185.75', 'AUD']
# ['NetLiquidationByCurrency', '695185.75', 'AUD']
# ['NetLiquidationByCurrency', '2687002.1857', 'BASE']
# ['NetLiquidationByCurrency', '2687002.1857', 'BASE']
# ['NetLiquidationByCurrency', '682107.96', 'CAD']
# ['NetLiquidationByCurrency', '682107.96', 'CAD']
# ['NetLiquidationByCurrency', '188.63', 'CHF']
# ['NetLiquidationByCurrency', '188.63', 'CHF']
# ['NetLiquidationByCurrency', '853.35', 'CNH']
# ['NetLiquidationByCurrency', '853.35', 'CNH']
# ['NetLiquidationByCurrency', '2372.78', 'CZK']
# ['NetLiquidationByCurrency', '2372.78', 'CZK']
# ['NetLiquidationByCurrency', '895.20', 'EUR']
# ['NetLiquidationByCurrency', '895.20', 'EUR']
# ['NetLiquidationByCurrency', '-749281.71', 'GBP']
# ['NetLiquidationByCurrency', '-749281.71', 'GBP']
# ['NetLiquidationByCurrency', '-13.36', 'HKD']
# ['NetLiquidationByCurrency', '-13.36', 'HKD']
# ['NetLiquidationByCurrency', '5807.93', 'HUF']
# ['NetLiquidationByCurrency', '5807.93', 'HUF']
# ['NetLiquidationByCurrency', '555.98', 'ILS']
# ['NetLiquidationByCurrency', '555.98', 'ILS']
# ['NetLiquidationByCurrency', '158561.15', 'JPY']
# ['NetLiquidationByCurrency', '158561.15', 'JPY']
# ['NetLiquidationByCurrency', '22448.99', 'KRW']
# ['NetLiquidationByCurrency', '22448.99', 'KRW']
# ['NetLiquidationByCurrency', '555.39', 'NOK']
# ['NetLiquidationByCurrency', '555.39', 'NOK']
# ['NetLiquidationByCurrency', '355.50', 'NZD']
# ['NetLiquidationByCurrency', '355.50', 'NZD']
# ['NetLiquidationByCurrency', '2683.39', 'PLN']
# ['NetLiquidationByCurrency', '2683.39', 'PLN']
# ['NetLiquidationByCurrency', '2307.45', 'SEK']
# ['NetLiquidationByCurrency', '2307.45', 'SEK']
# ['NetLiquidationByCurrency', '185.26', 'SGD']
# ['NetLiquidationByCurrency', '185.26', 'SGD']
# ['NetLiquidationByCurrency', '30638.18', 'TRY']
# ['NetLiquidationByCurrency', '30638.18', 'TRY']
# ['NetLiquidationByCurrency', '335222.20', 'USD']
# ['NetLiquidationByCurrency', '335222.20', 'USD']
# ['NetLiquidationByCurrency', '-34372.41', 'ZAR']
# ['NetLiquidationByCurrency', '-34372.41', 'ZAR']
# ['NetLiquidationUncertainty', '0.00', 'HKD']
# ['NetLiquidationUncertainty', '0.00', 'HKD']
# ['OptionMarketValue', '0.00', 'AUD']
# ['OptionMarketValue', '0.00', 'AUD']
# ['OptionMarketValue', '0.00', 'BASE']
# ['OptionMarketValue', '0.00', 'BASE']
# ['OptionMarketValue', '0.00', 'CAD']
# ['OptionMarketValue', '0.00', 'CAD']
# ['OptionMarketValue', '0.00', 'CHF']
# ['OptionMarketValue', '0.00', 'CHF']
# ['OptionMarketValue', '0.00', 'CNH']
# ['OptionMarketValue', '0.00', 'CNH']
# ['OptionMarketValue', '0.00', 'CZK']
# ['OptionMarketValue', '0.00', 'CZK']
# ['OptionMarketValue', '0.00', 'EUR']
# ['OptionMarketValue', '0.00', 'EUR']
# ['OptionMarketValue', '0.00', 'GBP']
# ['OptionMarketValue', '0.00', 'GBP']
# ['OptionMarketValue', '0.00', 'HKD']
# ['OptionMarketValue', '0.00', 'HKD']
# ['OptionMarketValue', '0.00', 'HUF']
# ['OptionMarketValue', '0.00', 'HUF']
# ['OptionMarketValue', '0.00', 'ILS']
# ['OptionMarketValue', '0.00', 'ILS']
# ['OptionMarketValue', '0.00', 'JPY']
# ['OptionMarketValue', '0.00', 'JPY']
# ['OptionMarketValue', '0.00', 'KRW']
# ['OptionMarketValue', '0.00', 'KRW']
# ['OptionMarketValue', '0.00', 'NOK']
# ['OptionMarketValue', '0.00', 'NOK']
# ['OptionMarketValue', '0.00', 'NZD']
# ['OptionMarketValue', '0.00', 'NZD']
# ['OptionMarketValue', '0.00', 'PLN']
# ['OptionMarketValue', '0.00', 'PLN']
# ['OptionMarketValue', '0.00', 'SEK']
# ['OptionMarketValue', '0.00', 'SEK']
# ['OptionMarketValue', '0.00', 'SGD']
# ['OptionMarketValue', '0.00', 'SGD']
# ['OptionMarketValue', '0.00', 'TRY']
# ['OptionMarketValue', '0.00', 'TRY']
# ['OptionMarketValue', '0.00', 'USD']
# ['OptionMarketValue', '0.00', 'USD']
# ['OptionMarketValue', '0.00', 'ZAR']
# ['OptionMarketValue', '0.00', 'ZAR']
# ['PASharesValue', '0.00', 'HKD']
# ['PASharesValue', '0.00', 'HKD']
# ['PASharesValue-S', '0.00', 'HKD']
# ['PASharesValue-S', '0.00', 'HKD']
# ['PhysicalCertificateValue', '0.00', 'HKD']
# ['PhysicalCertificateValue', '0.00', 'HKD']
# ['PhysicalCertificateValue-S', '0.00', 'HKD']
# ['PhysicalCertificateValue-S', '0.00', 'HKD']
# ['PostExpirationExcess', '0.00', 'HKD']
# ['PostExpirationExcess', '0.00', 'HKD']
# ['PostExpirationExcess-S', '0.00', 'HKD']
# ['PostExpirationExcess-S', '0.00', 'HKD']
# ['PostExpirationMargin', '0.00', 'HKD']
# ['PostExpirationMargin', '0.00', 'HKD']
# ['PostExpirationMargin-S', '0.00', 'HKD']
# ['PostExpirationMargin-S', '0.00', 'HKD']
# ['RealCurrency', 'AUD', 'AUD']
# ['RealCurrency', 'AUD', 'AUD']
# ['RealCurrency', 'BASE', 'BASE']
# ['RealCurrency', 'BASE', 'BASE']
# ['RealCurrency', 'CAD', 'CAD']
# ['RealCurrency', 'CAD', 'CAD']
# ['RealCurrency', 'CHF', 'CHF']
# ['RealCurrency', 'CHF', 'CHF']
# ['RealCurrency', 'CNH', 'CNH']
# ['RealCurrency', 'CNH', 'CNH']
# ['RealCurrency', 'CZK', 'CZK']
# ['RealCurrency', 'CZK', 'CZK']
# ['RealCurrency', 'EUR', 'EUR']
# ['RealCurrency', 'EUR', 'EUR']
# ['RealCurrency', 'GBP', 'GBP']
# ['RealCurrency', 'GBP', 'GBP']
# ['RealCurrency', 'HKD', 'HKD']
# ['RealCurrency', 'HKD', 'HKD']
# ['RealCurrency', 'HUF', 'HUF']
# ['RealCurrency', 'HUF', 'HUF']
# ['RealCurrency', 'ILS', 'ILS']
# ['RealCurrency', 'ILS', 'ILS']
# ['RealCurrency', 'JPY', 'JPY']
# ['RealCurrency', 'JPY', 'JPY']
# ['RealCurrency', 'KRW', 'KRW']
# ['RealCurrency', 'KRW', 'KRW']
# ['RealCurrency', 'NOK', 'NOK']
# ['RealCurrency', 'NOK', 'NOK']
# ['RealCurrency', 'NZD', 'NZD']
# ['RealCurrency', 'NZD', 'NZD']
# ['RealCurrency', 'PLN', 'PLN']
# ['RealCurrency', 'PLN', 'PLN']
# ['RealCurrency', 'SEK', 'SEK']
# ['RealCurrency', 'SEK', 'SEK']
# ['RealCurrency', 'SGD', 'SGD']
# ['RealCurrency', 'SGD', 'SGD']
# ['RealCurrency', 'TRY', 'TRY']
# ['RealCurrency', 'TRY', 'TRY']
# ['RealCurrency', 'USD', 'USD']
# ['RealCurrency', 'USD', 'USD']
# ['RealCurrency', 'ZAR', 'ZAR']
# ['RealCurrency', 'ZAR', 'ZAR']
# ['RealizedPnL', '0.00', 'AUD']
# ['RealizedPnL', '0.00', 'AUD']
# ['RealizedPnL', '0.00', 'BASE']
# ['RealizedPnL', '0.00', 'BASE']
# ['RealizedPnL', '0.00', 'CAD']
# ['RealizedPnL', '0.00', 'CAD']
# ['RealizedPnL', '0.00', 'CHF']
# ['RealizedPnL', '0.00', 'CHF']
# ['RealizedPnL', '0.00', 'CNH']
# ['RealizedPnL', '0.00', 'CNH']
# ['RealizedPnL', '0.00', 'CZK']
# ['RealizedPnL', '0.00', 'CZK']
# ['RealizedPnL', '0.00', 'EUR']
# ['RealizedPnL', '0.00', 'EUR']
# ['RealizedPnL', '0.00', 'GBP']
# ['RealizedPnL', '0.00', 'GBP']
# ['RealizedPnL', '0.00', 'HKD']
# ['RealizedPnL', '0.00', 'HKD']
# ['RealizedPnL', '0.00', 'HUF']
# ['RealizedPnL', '0.00', 'HUF']
# ['RealizedPnL', '0.00', 'ILS']
# ['RealizedPnL', '0.00', 'ILS']
# ['RealizedPnL', '0.00', 'JPY']
# ['RealizedPnL', '0.00', 'JPY']
# ['RealizedPnL', '0.00', 'KRW']
# ['RealizedPnL', '0.00', 'KRW']
# ['RealizedPnL', '0.00', 'NOK']
# ['RealizedPnL', '0.00', 'NOK']
# ['RealizedPnL', '0.00', 'NZD']
# ['RealizedPnL', '0.00', 'NZD']
# ['RealizedPnL', '0.00', 'PLN']
# ['RealizedPnL', '0.00', 'PLN']
# ['RealizedPnL', '0.00', 'SEK']
# ['RealizedPnL', '0.00', 'SEK']
# ['RealizedPnL', '0.00', 'SGD']
# ['RealizedPnL', '0.00', 'SGD']
# ['RealizedPnL', '0.00', 'TRY']
# ['RealizedPnL', '0.00', 'TRY']
# ['RealizedPnL', '0.00', 'USD']
# ['RealizedPnL', '0.00', 'USD']
# ['RealizedPnL', '0.00', 'ZAR']
# ['RealizedPnL', '0.00', 'ZAR']
# ['SegmentTitle-S', 'Securities', '']
# ['SegmentTitle-S', 'Securities', '']
# ['StockMarketValue', '0.00', 'AUD']
# ['StockMarketValue', '0.00', 'AUD']
# ['StockMarketValue', '0.00', 'BASE']
# ['StockMarketValue', '0.00', 'BASE']
# ['StockMarketValue', '0.00', 'CAD']
# ['StockMarketValue', '0.00', 'CAD']
# ['StockMarketValue', '0.00', 'CHF']
# ['StockMarketValue', '0.00', 'CHF']
# ['StockMarketValue', '0.00', 'CNH']
# ['StockMarketValue', '0.00', 'CNH']
# ['StockMarketValue', '0.00', 'CZK']
# ['StockMarketValue', '0.00', 'CZK']
# ['StockMarketValue', '0.00', 'EUR']
# ['StockMarketValue', '0.00', 'EUR']
# ['StockMarketValue', '0.00', 'GBP']
# ['StockMarketValue', '0.00', 'GBP']
# ['StockMarketValue', '0.00', 'HKD']
# ['StockMarketValue', '0.00', 'HKD']
# ['StockMarketValue', '0.00', 'HUF']
# ['StockMarketValue', '0.00', 'HUF']
# ['StockMarketValue', '0.00', 'ILS']
# ['StockMarketValue', '0.00', 'ILS']
# ['StockMarketValue', '0.00', 'JPY']
# ['StockMarketValue', '0.00', 'JPY']
# ['StockMarketValue', '0.00', 'KRW']
# ['StockMarketValue', '0.00', 'KRW']
# ['StockMarketValue', '0.00', 'NOK']
# ['StockMarketValue', '0.00', 'NOK']
# ['StockMarketValue', '0.00', 'NZD']
# ['StockMarketValue', '0.00', 'NZD']
# ['StockMarketValue', '0.00', 'PLN']
# ['StockMarketValue', '0.00', 'PLN']
# ['StockMarketValue', '0.00', 'SEK']
# ['StockMarketValue', '0.00', 'SEK']
# ['StockMarketValue', '0.00', 'SGD']
# ['StockMarketValue', '0.00', 'SGD']
# ['StockMarketValue', '0.00', 'TRY']
# ['StockMarketValue', '0.00', 'TRY']
# ['StockMarketValue', '0.00', 'USD']
# ['StockMarketValue', '0.00', 'USD']
# ['StockMarketValue', '0.00', 'ZAR']
# ['StockMarketValue', '0.00', 'ZAR']
# ['TBillValue', '0.00', 'AUD']
# ['TBillValue', '0.00', 'AUD']
# ['TBillValue', '0.00', 'BASE']
# ['TBillValue', '0.00', 'BASE']
# ['TBillValue', '0.00', 'CAD']
# ['TBillValue', '0.00', 'CAD']
# ['TBillValue', '0.00', 'CHF']
# ['TBillValue', '0.00', 'CHF']
# ['TBillValue', '0.00', 'CNH']
# ['TBillValue', '0.00', 'CNH']
# ['TBillValue', '0.00', 'CZK']
# ['TBillValue', '0.00', 'CZK']
# ['TBillValue', '0.00', 'EUR']
# ['TBillValue', '0.00', 'EUR']
# ['TBillValue', '0.00', 'GBP']
# ['TBillValue', '0.00', 'GBP']
# ['TBillValue', '0.00', 'HKD']
# ['TBillValue', '0.00', 'HKD']
# ['TBillValue', '0.00', 'HUF']
# ['TBillValue', '0.00', 'HUF']
# ['TBillValue', '0.00', 'ILS']
# ['TBillValue', '0.00', 'ILS']
# ['TBillValue', '0.00', 'JPY']
# ['TBillValue', '0.00', 'JPY']
# ['TBillValue', '0.00', 'KRW']
# ['TBillValue', '0.00', 'KRW']
# ['TBillValue', '0.00', 'NOK']
# ['TBillValue', '0.00', 'NOK']
# ['TBillValue', '0.00', 'NZD']
# ['TBillValue', '0.00', 'NZD']
# ['TBillValue', '0.00', 'PLN']
# ['TBillValue', '0.00', 'PLN']
# ['TBillValue', '0.00', 'SEK']
# ['TBillValue', '0.00', 'SEK']
# ['TBillValue', '0.00', 'SGD']
# ['TBillValue', '0.00', 'SGD']
# ['TBillValue', '0.00', 'TRY']
# ['TBillValue', '0.00', 'TRY']
# ['TBillValue', '0.00', 'USD']
# ['TBillValue', '0.00', 'USD']
# ['TBillValue', '0.00', 'ZAR']
# ['TBillValue', '0.00', 'ZAR']
# ['TBondValue', '0.00', 'AUD']
# ['TBondValue', '0.00', 'AUD']
# ['TBondValue', '0.00', 'BASE']
# ['TBondValue', '0.00', 'BASE']
# ['TBondValue', '0.00', 'CAD']
# ['TBondValue', '0.00', 'CAD']
# ['TBondValue', '0.00', 'CHF']
# ['TBondValue', '0.00', 'CHF']
# ['TBondValue', '0.00', 'CNH']
# ['TBondValue', '0.00', 'CNH']
# ['TBondValue', '0.00', 'CZK']
# ['TBondValue', '0.00', 'CZK']
# ['TBondValue', '0.00', 'EUR']
# ['TBondValue', '0.00', 'EUR']
# ['TBondValue', '0.00', 'GBP']
# ['TBondValue', '0.00', 'GBP']
# ['TBondValue', '0.00', 'HKD']
# ['TBondValue', '0.00', 'HKD']
# ['TBondValue', '0.00', 'HUF']
# ['TBondValue', '0.00', 'HUF']
# ['TBondValue', '0.00', 'ILS']
# ['TBondValue', '0.00', 'ILS']
# ['TBondValue', '0.00', 'JPY']
# ['TBondValue', '0.00', 'JPY']
# ['TBondValue', '0.00', 'KRW']
# ['TBondValue', '0.00', 'KRW']
# ['TBondValue', '0.00', 'NOK']
# ['TBondValue', '0.00', 'NOK']
# ['TBondValue', '0.00', 'NZD']
# ['TBondValue', '0.00', 'NZD']
# ['TBondValue', '0.00', 'PLN']
# ['TBondValue', '0.00', 'PLN']
# ['TBondValue', '0.00', 'SEK']
# ['TBondValue', '0.00', 'SEK']
# ['TBondValue', '0.00', 'SGD']
# ['TBondValue', '0.00', 'SGD']
# ['TBondValue', '0.00', 'TRY']
# ['TBondValue', '0.00', 'TRY']
# ['TBondValue', '0.00', 'USD']
# ['TBondValue', '0.00', 'USD']
# ['TBondValue', '0.00', 'ZAR']
# ['TBondValue', '0.00', 'ZAR']
# ['TotalCashBalance', '695244.24', 'AUD']
# ['TotalCashBalance', '695244.24', 'AUD']
# ['TotalCashBalance', '2678673.6881', 'BASE']
# ['TotalCashBalance', '2678673.6881', 'BASE']
# ['TotalCashBalance', '682342.92', 'CAD']
# ['TotalCashBalance', '682342.92', 'CAD']
# ['TotalCashBalance', '190.16', 'CHF']
# ['TotalCashBalance', '190.16', 'CHF']
# ['TotalCashBalance', '853.35', 'CNH']
# ['TotalCashBalance', '853.35', 'CNH']
# ['TotalCashBalance', '2372.78', 'CZK']
# ['TotalCashBalance', '2372.78', 'CZK']
# ['TotalCashBalance', '895.20', 'EUR']
# ['TotalCashBalance', '895.20', 'EUR']
# ['TotalCashBalance', '-749384.75', 'GBP']
# ['TotalCashBalance', '-749384.75', 'GBP']
# ['TotalCashBalance', '-13.36', 'HKD']
# ['TotalCashBalance', '-13.36', 'HKD']
# ['TotalCashBalance', '6412.76', 'HUF']
# ['TotalCashBalance', '6412.76', 'HUF']
# ['TotalCashBalance', '555.98', 'ILS']
# ['TotalCashBalance', '555.98', 'ILS']
# ['TotalCashBalance', '164827.15', 'JPY']
# ['TotalCashBalance', '164827.15', 'JPY']
# ['TotalCashBalance', '22448.99', 'KRW']
# ['TotalCashBalance', '22448.99', 'KRW']
# ['TotalCashBalance', '555.39', 'NOK']
# ['TotalCashBalance', '555.39', 'NOK']
# ['TotalCashBalance', '355.50', 'NZD']
# ['TotalCashBalance', '355.50', 'NZD']
# ['TotalCashBalance', '2683.39', 'PLN']
# ['TotalCashBalance', '2683.39', 'PLN']
# ['TotalCashBalance', '2307.45', 'SEK']
# ['TotalCashBalance', '2307.45', 'SEK']
# ['TotalCashBalance', '185.26', 'SGD']
# ['TotalCashBalance', '185.26', 'SGD']
# ['TotalCashBalance', '30638.18', 'TRY']
# ['TotalCashBalance', '30638.18', 'TRY']
# ['TotalCashBalance', '334022.06', 'USD']
# ['TotalCashBalance', '334022.06', 'USD']
# ['TotalCashBalance', '-34153.66', 'ZAR']
# ['TotalCashBalance', '-34153.66', 'ZAR']
# ['TotalCashValue', '2678673.69', 'HKD']
# ['TotalCashValue', '2678673.69', 'HKD']
# ['TotalCashValue-S', '2678673.69', 'HKD']
# ['TotalCashValue-S', '2678673.69', 'HKD']
# ['TotalDebitCardPendingCharges', '0.00', 'HKD']
# ['TotalDebitCardPendingCharges', '0.00', 'HKD']
# ['TotalDebitCardPendingCharges-S', '0.00', 'HKD']
# ['TotalDebitCardPendingCharges-S', '0.00', 'HKD']
# ['TradingType-S', 'STKNOPT', '']
# ['TradingType-S', 'STKNOPT', '']
# ['UnrealizedPnL', '0.00', 'AUD']
# ['UnrealizedPnL', '0.00', 'AUD']
# ['UnrealizedPnL', '0.00', 'BASE']
# ['UnrealizedPnL', '0.00', 'BASE']
# ['UnrealizedPnL', '0.00', 'CAD']
# ['UnrealizedPnL', '0.00', 'CAD']
# ['UnrealizedPnL', '0.00', 'CHF']
# ['UnrealizedPnL', '0.00', 'CHF']
# ['UnrealizedPnL', '0.00', 'CNH']
# ['UnrealizedPnL', '0.00', 'CNH']
# ['UnrealizedPnL', '0.00', 'CZK']
# ['UnrealizedPnL', '0.00', 'CZK']
# ['UnrealizedPnL', '0.00', 'EUR']
# ['UnrealizedPnL', '0.00', 'EUR']
# ['UnrealizedPnL', '0.00', 'GBP']
# ['UnrealizedPnL', '0.00', 'GBP']
# ['UnrealizedPnL', '0.00', 'HKD']
# ['UnrealizedPnL', '0.00', 'HKD']
# ['UnrealizedPnL', '0.00', 'HUF']
# ['UnrealizedPnL', '0.00', 'HUF']
# ['UnrealizedPnL', '0.00', 'ILS']
# ['UnrealizedPnL', '0.00', 'ILS']
# ['UnrealizedPnL', '0.00', 'JPY']
# ['UnrealizedPnL', '0.00', 'JPY']
# ['UnrealizedPnL', '0.00', 'KRW']
# ['UnrealizedPnL', '0.00', 'KRW']
# ['UnrealizedPnL', '0.00', 'NOK']
# ['UnrealizedPnL', '0.00', 'NOK']
# ['UnrealizedPnL', '0.00', 'NZD']
# ['UnrealizedPnL', '0.00', 'NZD']
# ['UnrealizedPnL', '0.00', 'PLN']
# ['UnrealizedPnL', '0.00', 'PLN']
# ['UnrealizedPnL', '0.00', 'SEK']
# ['UnrealizedPnL', '0.00', 'SEK']
# ['UnrealizedPnL', '0.00', 'SGD']
# ['UnrealizedPnL', '0.00', 'SGD']
# ['UnrealizedPnL', '0.00', 'TRY']
# ['UnrealizedPnL', '0.00', 'TRY']
# ['UnrealizedPnL', '0.00', 'USD']
# ['UnrealizedPnL', '0.00', 'USD']
# ['UnrealizedPnL', '0.00', 'ZAR']
# ['UnrealizedPnL', '0.00', 'ZAR']
# ['WarrantValue', '0.00', 'AUD']
# ['WarrantValue', '0.00', 'AUD']
# ['WarrantValue', '0.00', 'BASE']
# ['WarrantValue', '0.00', 'BASE']
# ['WarrantValue', '0.00', 'CAD']
# ['WarrantValue', '0.00', 'CAD']
# ['WarrantValue', '0.00', 'CHF']
# ['WarrantValue', '0.00', 'CHF']
# ['WarrantValue', '0.00', 'CNH']
# ['WarrantValue', '0.00', 'CNH']
# ['WarrantValue', '0.00', 'CZK']
# ['WarrantValue', '0.00', 'CZK']
# ['WarrantValue', '0.00', 'EUR']
# ['WarrantValue', '0.00', 'EUR']
# ['WarrantValue', '0.00', 'GBP']
# ['WarrantValue', '0.00', 'GBP']
# ['WarrantValue', '0.00', 'HKD']
# ['WarrantValue', '0.00', 'HKD']
# ['WarrantValue', '0.00', 'HUF']
# ['WarrantValue', '0.00', 'HUF']
# ['WarrantValue', '0.00', 'ILS']
# ['WarrantValue', '0.00', 'ILS']
# ['WarrantValue', '0.00', 'JPY']
# ['WarrantValue', '0.00', 'JPY']
# ['WarrantValue', '0.00', 'KRW']
# ['WarrantValue', '0.00', 'KRW']
# ['WarrantValue', '0.00', 'NOK']
# ['WarrantValue', '0.00', 'NOK']
# ['WarrantValue', '0.00', 'NZD']
# ['WarrantValue', '0.00', 'NZD']
# ['WarrantValue', '0.00', 'PLN']
# ['WarrantValue', '0.00', 'PLN']
# ['WarrantValue', '0.00', 'SEK']
# ['WarrantValue', '0.00', 'SEK']
# ['WarrantValue', '0.00', 'SGD']
# ['WarrantValue', '0.00', 'SGD']
# ['WarrantValue', '0.00', 'TRY']
# ['WarrantValue', '0.00', 'TRY']
# ['WarrantValue', '0.00', 'USD']
# ['WarrantValue', '0.00', 'USD']
# ['WarrantValue', '0.00', 'ZAR']
# ['WarrantValue', '0.00', 'ZAR']
# [140036853022096: 15016138,AUD,CASH,,0,0,,,IDEALPRO,CAD,AUD.CAD,AUD.CAD,False,,,,combo:, Decimal('18839.8'), 0.8725, 16437.73, 0.8820378, -179.69, 0.0, 'U6861179']
# [140036843916928: 15016125,AUD,CASH,,0,0,,,IDEALPRO,CHF,AUD.CHF,AUD.CHF,False,,,,combo:, Decimal('15628'), 0.56675, 8857.17, 0.61556, -762.8, 0.0, 'U6861179']
# [140036843917120: 15016128,AUD,CASH,,0,0,,,IDEALPRO,HKD,AUD.HKD,AUD.HKD,False,,,,combo:, Decimal('-48941'), 5.03690005, -246510.93, 5.5488166, 25053.71, 0.0, 'U6861179']
# [140036843937648: 15016133,AUD,CASH,,0,0,,,IDEALPRO,JPY,AUD.JPY,AUD.JPY,False,,,,combo:, Decimal('158949'), 93.9850006, 14938821.86, 95.5418683, -247462.56, 0.0, 'U6861179']
# [140036969523856: 39453424,AUD,CASH,,0,0,,,IDEALPRO,NZD,AUD.NZD,AUD.NZD,False,,,,combo:, Decimal('32500'), 1.08597505, 35294.19, 1.05494, 1008.64, 0.0, 'U6861179']
# [140036853390304: 61664938,AUD,CASH,,0,0,,,IDEALPRO,SGD,AUD.SGD,AUD.SGD,False,,,,combo:, Decimal('8389'), 0.87050005, 7302.62, 0.92555445, -461.85, 0.0, 'U6861179']
# [140036853390640: 14433401,AUD,CASH,,0,0,,,IDEALPRO,USD,AUD.USD,AUD.USD,False,,,,combo:, Decimal('-174333'), 0.641975, -111917.43, 0.66608, 4202.3, 0.0, 'U6861179']
# [140036853388336: 15016234,CAD,CASH,,0,0,,,IDEALPRO,CHF,CAD.CHF,CAD.CHF,False,,,,combo:, Decimal('-2335'), 0.649575, -1516.76, 0.75365765, 243.03, 0.0, 'U6861179']
# [140036965403328: 15016239,CAD,CASH,,0,0,,,IDEALPRO,HKD,CAD.HKD,CAD.HKD,False,,,,combo:, Decimal('43744'), 5.77285005, 252527.55, 6.12835545, -15551.23, 0.0, 'U6861179']
# [140036853366208: 15016241,CAD,CASH,,0,0,,,IDEALPRO,JPY,CAD.JPY,CAD.JPY,False,,,,combo:, Decimal('83602'), 107.7124939, 9004979.91, 100.712922, 585178.21, 0.0, 'U6861179']
# [140036853454208: 14321010,CHF,CASH,,0,0,,,IDEALPRO,JPY,CHF.JPY,CHF.JPY,False,,,,combo:, Decimal('23133.1459'), 165.82499695, 3836053.85, 158.5553033, 168170.88, 0.0, 'U6861179']
# [140036965419280: 37893493,CHF,CASH,,0,0,,,IDEALPRO,SEK,CHF.SEK,CHF.SEK,False,,,,combo:, Decimal('-14795'), 12.5029001, -184980.41, 10.7674, -25676.72, 0.0, 'U6861179']
# [140036843880352: 174179663,CNH,CASH,,0,0,,,IDEALPRO,HKD,CNH.HKD,CNH.HKD,False,,,,combo:, Decimal('-1687.68'), 1.075225, -1814.64, 1.05726935, -30.3, 0.0, 'U6861179']
# [140036843880160: 114900065,CNH,CASH,,0,0,,,IDEALPRO,JPY,CNH.JPY,CNH.JPY,False,,,,combo:, Decimal('10000'), 20.0625, 200625.0, 20.295, -2325.0, 0.0, 'U6861179']
# [140036963422656: 15016065,EUR,CASH,,0,0,,,IDEALPRO,AUD,EUR.AUD,EUR.AUD,False,,,,combo:, Decimal('24465'), 1.68495, 41222.3, 1.62995285, 1345.5, 0.0, 'U6861179']
# [140036853214848: 15016068,EUR,CASH,,0,0,,,IDEALPRO,CAD,EUR.CAD,EUR.CAD,False,,,,combo:, Decimal('-11946'), 1.47017505, -17562.71, 1.42882, -494.03, 0.0, 'U6861179']
# [140036853215136: 12087817,EUR,CASH,,0,0,,,IDEALPRO,CHF,EUR.CHF,EUR.CHF,False,,,,combo:, Decimal('70151'), 0.954975, 66992.45, 0.98593195, -2171.66, 0.0, 'U6861179']
# [140036853211920: 12087807,EUR,CASH,,0,0,,,IDEALPRO,GBP,EUR.GBP,EUR.GBP,False,,,,combo:, Decimal('83863'), 0.858425, 71990.1, 0.8575, 77.58, 0.0, 'U6861179']
# [140036853214224: 12345770,EUR,CASH,,0,0,,,IDEALPRO,HKD,EUR.HKD,EUR.HKD,False,,,,combo:, Decimal('46980'), 8.48705005, 398721.61, 9.3316085, -39677.36, 0.0, 'U6861179']
# [140036943236832: 75015675,EUR,CASH,,0,0,,,IDEALPRO,HUF,EUR.HUF,EUR.HUF,False,,,,combo:, Decimal('-2440'), 382.55999755, -933446.39, 379.62, -7173.59, 0.0, 'U6861179']
# [140036943236400: 14321016,EUR,CASH,,0,0,,,IDEALPRO,JPY,EUR.JPY,EUR.JPY,False,,,,combo:, Decimal('-204550'), 158.35749815, -32392026.25, 156.4784149, -384366.48, 0.0, 'U6861179']
# [140036943235920: 39453434,EUR,CASH,,0,0,,,IDEALPRO,NOK,EUR.NOK,EUR.NOK,False,,,,combo:, Decimal('7155'), 11.61917495, 83135.2, 9.56546495, 14694.3, 0.0, 'U6861179']
# [140036943236928: 37893488,EUR,CASH,,0,0,,,IDEALPRO,SEK,EUR.SEK,EUR.SEK,False,,,,combo:, Decimal('-7506'), 11.9399004, -89620.89, 11.6737949, -1997.39, 0.0, 'U6861179']
# [140036943235872: 37928764,EUR,CASH,,0,0,,,IDEALPRO,SGD,EUR.SGD,EUR.SGD,False,,,,combo:, Decimal('38233'), 1.46677495, 56079.21, 1.58351945, -4463.49, 0.0, 'U6861179']
# [140036943236784: 12087792,EUR,CASH,,0,0,,,IDEALPRO,USD,EUR.USD,EUR.USD,False,,,,combo:, Decimal('-346834'), 1.08177495, -375196.33, 1.11333685, 10946.75, 0.0, 'U6861179']
# [140036943236976: 15016075,GBP,CASH,,0,0,,,IDEALPRO,AUD,GBP.AUD,GBP.AUD,False,,,,combo:, Decimal('-343532'), 1.96290005, -674318.98, 1.96313605, 81.08, 0.0, 'U6861179']
# [140036943235968: 15016078,GBP,CASH,,0,0,,,IDEALPRO,CAD,GBP.CAD,GBP.CAD,False,,,,combo:, Decimal('-401901'), 1.7126, -688295.65, 1.711753, -340.41, 0.0, 'U6861179']
# [140036960956224: 12087826,GBP,CASH,,0,0,,,IDEALPRO,CHF,GBP.CHF,GBP.CHF,False,,,,combo:, Decimal('-22187'), 1.11242495, -24681.37, 1.13075, 406.58, 0.0, 'U6861179']
# [140036852889200: 12345775,GBP,CASH,,0,0,,,IDEALPRO,HKD,GBP.HKD,GBP.HKD,False,,,,combo:, Decimal('-8053'), 9.88650035, -79615.99, 10.39345415, 4082.5, 0.0, 'U6861179']
# [140036852889440: 14321015,GBP,CASH,,0,0,,,IDEALPRO,JPY,GBP.JPY,GBP.JPY,False,,,,combo:, Decimal('45146'), 184.4724884, 8328194.96, 181.99110315, 112024.62, 0.0, 'U6861179']
# ...
# ['IssuerOptionValue', '0.00', 'NZD']
# ['IssuerOptionValue', '0.00', 'NZD']
# ['IssuerOptionValue', '0.00', 'SGD']
# ['IssuerOptionValue', '0.00', 'SGD']
# ['IssuerOptionValue', '0.00', 'TRY']
# ['IssuerOptionValue', '0.00', 'TRY']
# ['IssuerOptionValue', '0.00', 'USD']
# ['IssuerOptionValue', '0.00', 'USD']
# ['IssuerOptionValue', '0.00', 'ZAR']
# ['IssuerOptionValue', '0.00', 'ZAR']
# ['Leverage-S', '0.00', '']
# ['Leverage-S', '0.00', '']
# ['LookAheadAvailableFunds', '215886.59', 'EUR']
# ['LookAheadAvailableFunds', '215886.59', 'EUR']
# ['LookAheadAvailableFunds-S', '215886.59', 'EUR']
# ['LookAheadAvailableFunds-S', '215886.59', 'EUR']
# ['LookAheadExcessLiquidity', '216018.20', 'EUR']
# ['LookAheadExcessLiquidity', '216018.20', 'EUR']
# ['LookAheadExcessLiquidity-S', '216018.20', 'EUR']
# ['LookAheadExcessLiquidity-S', '216018.20', 'EUR']
# ['LookAheadInitMarginReq', '0.00', 'EUR']
# ['LookAheadInitMarginReq', '0.00', 'EUR']
# ['LookAheadInitMarginReq-S', '0.00', 'EUR']
# ['LookAheadInitMarginReq-S', '0.00', 'EUR']
# ['LookAheadMaintMarginReq', '0.00', 'EUR']
# ['LookAheadMaintMarginReq', '0.00', 'EUR']
# ['LookAheadMaintMarginReq-S', '0.00', 'EUR']
# ['LookAheadMaintMarginReq-S', '0.00', 'EUR']
# ['LookAheadNextChange', '0', '']
# ['LookAheadNextChange', '0', '']
# ['MaintMarginReq', '0.00', 'EUR']
# ['MaintMarginReq', '0.00', 'EUR']
# ['MaintMarginReq-S', '0.00', 'EUR']
# ['MaintMarginReq-S', '0.00', 'EUR']
# ['MoneyMarketFundValue', '0.00', 'AUD']
# ['MoneyMarketFundValue', '0.00', 'AUD']
# ['MoneyMarketFundValue', '0.00', 'BASE']
# ['MoneyMarketFundValue', '0.00', 'BASE']
# ['MoneyMarketFundValue', '0.00', 'EUR']
# ['MoneyMarketFundValue', '0.00', 'EUR']
# ['MoneyMarketFundValue', '0.00', 'GBP']
# ['MoneyMarketFundValue', '0.00', 'GBP']
# ['MoneyMarketFundValue', '0.00', 'HKD']
# ['MoneyMarketFundValue', '0.00', 'HKD']
# ['MoneyMarketFundValue', '0.00', 'ILS']
# ['MoneyMarketFundValue', '0.00', 'ILS']
# ['MoneyMarketFundValue', '0.00', 'JPY']
# ['MoneyMarketFundValue', '0.00', 'JPY']
# ['MoneyMarketFundValue', '0.00', 'KRW']
# ['MoneyMarketFundValue', '0.00', 'KRW']
# ['MoneyMarketFundValue', '0.00', 'NZD']
# ['MoneyMarketFundValue', '0.00', 'NZD']
# ['MoneyMarketFundValue', '0.00', 'SGD']
# ['MoneyMarketFundValue', '0.00', 'SGD']
# ['MoneyMarketFundValue', '0.00', 'TRY']
# ['MoneyMarketFundValue', '0.00', 'TRY']
# ['MoneyMarketFundValue', '0.00', 'USD']
# ['MoneyMarketFundValue', '0.00', 'USD']
# ['MoneyMarketFundValue', '0.00', 'ZAR']
# ['MoneyMarketFundValue', '0.00', 'ZAR']
# ['MutualFundValue', '0.00', 'AUD']
# ['MutualFundValue', '0.00', 'AUD']
# ['MutualFundValue', '0.00', 'BASE']
# ['MutualFundValue', '0.00', 'BASE']
# ['MutualFundValue', '0.00', 'EUR']
# ['MutualFundValue', '0.00', 'EUR']
# ['MutualFundValue', '0.00', 'GBP']
# ['MutualFundValue', '0.00', 'GBP']
# ['MutualFundValue', '0.00', 'HKD']
# ['MutualFundValue', '0.00', 'HKD']
# ['MutualFundValue', '0.00', 'ILS']
# ['MutualFundValue', '0.00', 'ILS']
# ['MutualFundValue', '0.00', 'JPY']
# ['MutualFundValue', '0.00', 'JPY']
# ['MutualFundValue', '0.00', 'KRW']
# ['MutualFundValue', '0.00', 'KRW']
# ['MutualFundValue', '0.00', 'NZD']
# ['MutualFundValue', '0.00', 'NZD']
# ['MutualFundValue', '0.00', 'SGD']
# ['MutualFundValue', '0.00', 'SGD']
# ['MutualFundValue', '0.00', 'TRY']
# ['MutualFundValue', '0.00', 'TRY']
# ['MutualFundValue', '0.00', 'USD']
# ['MutualFundValue', '0.00', 'USD']
# ['MutualFundValue', '0.00', 'ZAR']
# ['MutualFundValue', '0.00', 'ZAR']
# ['NLVAndMarginInReview', 'false', '']
# ['NLVAndMarginInReview', 'false', '']
# ['NetDividend', '0.00', 'AUD']
# ['NetDividend', '0.00', 'AUD']
# ['NetDividend', '0.00', 'BASE']
# ['NetDividend', '0.00', 'BASE']
# ['NetDividend', '0.00', 'EUR']
# ['NetDividend', '0.00', 'EUR']
# ['NetDividend', '0.00', 'GBP']
# ['NetDividend', '0.00', 'GBP']
# ['NetDividend', '0.00', 'HKD']
# ['NetDividend', '0.00', 'HKD']
# ['NetDividend', '0.00', 'ILS']
# ['NetDividend', '0.00', 'ILS']
# ['NetDividend', '0.00', 'JPY']
# ['NetDividend', '0.00', 'JPY']
# ['NetDividend', '0.00', 'KRW']
# ['NetDividend', '0.00', 'KRW']
# ['NetDividend', '0.00', 'NZD']
# ['NetDividend', '0.00', 'NZD']
# ['NetDividend', '0.00', 'SGD']
# ['NetDividend', '0.00', 'SGD']
# ['NetDividend', '0.00', 'TRY']
# ['NetDividend', '0.00', 'TRY']
# ['NetDividend', '0.00', 'USD']
# ['NetDividend', '0.00', 'USD']
# ['NetDividend', '0.00', 'ZAR']
# ['NetDividend', '0.00', 'ZAR']
# ['NetLiquidation', '216018.20', 'EUR']
# ['NetLiquidation', '216018.20', 'EUR']
# ['NetLiquidation-S', '216018.20', 'EUR']
# ['NetLiquidation-S', '216018.20', 'EUR']
# ['NetLiquidationByCurrency', '9.73', 'AUD']
# ['NetLiquidationByCurrency', '9.73', 'AUD']
# ['NetLiquidationByCurrency', '216018.2002', 'BASE']
# ['NetLiquidationByCurrency', '216018.2002', 'BASE']
# ['NetLiquidationByCurrency', '123.58', 'EUR']
# ['NetLiquidationByCurrency', '123.58', 'EUR']
# ['NetLiquidationByCurrency', '179.68', 'GBP']
# ['NetLiquidationByCurrency', '179.68', 'GBP']
# ['NetLiquidationByCurrency', '688.37', 'HKD']
# ['NetLiquidationByCurrency', '688.37', 'HKD']
# ['NetLiquidationByCurrency', '809.18', 'ILS']
# ['NetLiquidationByCurrency', '809.18', 'ILS']
# ['NetLiquidationByCurrency', '157603.66', 'JPY']
# ['NetLiquidationByCurrency', '157603.66', 'JPY']
# ['NetLiquidationByCurrency', '36631.99', 'KRW']
# ['NetLiquidationByCurrency', '36631.99', 'KRW']
# ['NetLiquidationByCurrency', '50.44', 'NZD']
# ['NetLiquidationByCurrency', '50.44', 'NZD']
# ['NetLiquidationByCurrency', '47.09', 'SGD']
# ['NetLiquidationByCurrency', '47.09', 'SGD']
# ['NetLiquidationByCurrency', '230.33', 'TRY']
# ['NetLiquidationByCurrency', '230.33', 'TRY']
# ['NetLiquidationByCurrency', '231840.66', 'USD']
# ['NetLiquidationByCurrency', '231840.66', 'USD']
# ['NetLiquidationByCurrency', '363.50', 'ZAR']
# ['NetLiquidationByCurrency', '363.50', 'ZAR']
# ['NetLiquidationUncertainty', '0.00', 'EUR']
# ['NetLiquidationUncertainty', '0.00', 'EUR']
# ['OptionMarketValue', '0.00', 'AUD']
# ['OptionMarketValue', '0.00', 'AUD']
# ['OptionMarketValue', '0.00', 'BASE']
# ['OptionMarketValue', '0.00', 'BASE']
# ['OptionMarketValue', '0.00', 'EUR']
# ['OptionMarketValue', '0.00', 'EUR']
# ['OptionMarketValue', '0.00', 'GBP']
# ['OptionMarketValue', '0.00', 'GBP']
# ['OptionMarketValue', '0.00', 'HKD']
# ['OptionMarketValue', '0.00', 'HKD']
# ['OptionMarketValue', '0.00', 'ILS']
# ['OptionMarketValue', '0.00', 'ILS']
# ['OptionMarketValue', '0.00', 'JPY']
# ['OptionMarketValue', '0.00', 'JPY']
# ['OptionMarketValue', '0.00', 'KRW']
# ['OptionMarketValue', '0.00', 'KRW']
# ['OptionMarketValue', '0.00', 'NZD']
# ['OptionMarketValue', '0.00', 'NZD']
# ['OptionMarketValue', '0.00', 'SGD']
# ['OptionMarketValue', '0.00', 'SGD']
# ['OptionMarketValue', '0.00', 'TRY']
# ['OptionMarketValue', '0.00', 'TRY']
# ['OptionMarketValue', '0.00', 'USD']
# ['OptionMarketValue', '0.00', 'USD']
# ['OptionMarketValue', '0.00', 'ZAR']
# ['OptionMarketValue', '0.00', 'ZAR']
# ['PASharesValue', '0.00', 'EUR']
# ['PASharesValue', '0.00', 'EUR']
# ['PASharesValue-S', '0.00', 'EUR']
# ['PASharesValue-S', '0.00', 'EUR']
# ['PhysicalCertificateValue', '0.00', 'EUR']
# ['PhysicalCertificateValue', '0.00', 'EUR']
# ['PhysicalCertificateValue-S', '0.00', 'EUR']
# ['PhysicalCertificateValue-S', '0.00', 'EUR']
# ['PostExpirationExcess', '0.00', 'EUR']
# ['PostExpirationExcess', '0.00', 'EUR']
# ['PostExpirationExcess-S', '0.00', 'EUR']
# ['PostExpirationExcess-S', '0.00', 'EUR']
# ['PostExpirationMargin', '0.00', 'EUR']
# ['PostExpirationMargin', '0.00', 'EUR']
# ['PostExpirationMargin-S', '0.00', 'EUR']
# ['PostExpirationMargin-S', '0.00', 'EUR']
# ['RealCurrency', 'AUD', 'AUD']
# ['RealCurrency', 'AUD', 'AUD']
# ['RealCurrency', 'BASE', 'BASE']
# ['RealCurrency', 'BASE', 'BASE']
# ['RealCurrency', 'EUR', 'EUR']
# ['RealCurrency', 'EUR', 'EUR']
# ['RealCurrency', 'GBP', 'GBP']
# ['RealCurrency', 'GBP', 'GBP']
# ['RealCurrency', 'HKD', 'HKD']
# ['RealCurrency', 'HKD', 'HKD']
# ['RealCurrency', 'ILS', 'ILS']
# ['RealCurrency', 'ILS', 'ILS']
# ['RealCurrency', 'JPY', 'JPY']
# ['RealCurrency', 'JPY', 'JPY']
# ['RealCurrency', 'KRW', 'KRW']
# ['RealCurrency', 'KRW', 'KRW']
# ['RealCurrency', 'NZD', 'NZD']
# ['RealCurrency', 'NZD', 'NZD']
# ['RealCurrency', 'SGD', 'SGD']
# ['RealCurrency', 'SGD', 'SGD']
# ['RealCurrency', 'TRY', 'TRY']
# ['RealCurrency', 'TRY', 'TRY']
# ['RealCurrency', 'USD', 'USD']
# ['RealCurrency', 'USD', 'USD']
# ['RealCurrency', 'ZAR', 'ZAR']
# ['RealCurrency', 'ZAR', 'ZAR']
# ['RealizedPnL', '0.00', 'AUD']
# ['RealizedPnL', '0.00', 'AUD']
# ['RealizedPnL', '0.00', 'BASE']
# ['RealizedPnL', '0.00', 'BASE']
# ['RealizedPnL', '0.00', 'EUR']
# ['RealizedPnL', '0.00', 'EUR']
# ['RealizedPnL', '0.00', 'GBP']
# ['RealizedPnL', '0.00', 'GBP']
# ['RealizedPnL', '0.00', 'HKD']
# ['RealizedPnL', '0.00', 'HKD']
# ['RealizedPnL', '0.00', 'ILS']
# ['RealizedPnL', '0.00', 'ILS']
# ['RealizedPnL', '0.00', 'JPY']
# ['RealizedPnL', '0.00', 'JPY']
# ['RealizedPnL', '0.00', 'KRW']
# ['RealizedPnL', '0.00', 'KRW']
# ['RealizedPnL', '0.00', 'NZD']
# ['RealizedPnL', '0.00', 'NZD']
# ['RealizedPnL', '0.00', 'SGD']
# ['RealizedPnL', '0.00', 'SGD']
# ['RealizedPnL', '0.00', 'TRY']
# ['RealizedPnL', '0.00', 'TRY']
# ['RealizedPnL', '0.00', 'USD']
# ['RealizedPnL', '0.00', 'USD']
# ['RealizedPnL', '0.00', 'ZAR']
# ['RealizedPnL', '0.00', 'ZAR']
# ['SegmentTitle-S', 'Securities', '']
# ['SegmentTitle-S', 'Securities', '']
# ['StockMarketValue', '0.00', 'AUD']
# ['StockMarketValue', '0.00', 'AUD']
# ['StockMarketValue', '0.00', 'BASE']
# ['StockMarketValue', '0.00', 'BASE']
# ['StockMarketValue', '0.00', 'EUR']
# ['StockMarketValue', '0.00', 'EUR']
# ['StockMarketValue', '0.00', 'GBP']
# ['StockMarketValue', '0.00', 'GBP']
# ['StockMarketValue', '0.00', 'HKD']
# ['StockMarketValue', '0.00', 'HKD']
# ['StockMarketValue', '0.00', 'ILS']
# ['StockMarketValue', '0.00', 'ILS']
# ['StockMarketValue', '0.00', 'JPY']
# ['StockMarketValue', '0.00', 'JPY']
# ['StockMarketValue', '0.00', 'KRW']
# ['StockMarketValue', '0.00', 'KRW']
# ['StockMarketValue', '0.00', 'NZD']
# ['StockMarketValue', '0.00', 'NZD']
# ['StockMarketValue', '0.00', 'SGD']
# ['StockMarketValue', '0.00', 'SGD']
# ['StockMarketValue', '0.00', 'TRY']
# ['StockMarketValue', '0.00', 'TRY']
# ['StockMarketValue', '0.00', 'USD']
# ['StockMarketValue', '0.00', 'USD']
# ['StockMarketValue', '0.00', 'ZAR']
# ['StockMarketValue', '0.00', 'ZAR']
# ['TBillValue', '0.00', 'AUD']
# ['TBillValue', '0.00', 'AUD']
# ['TBillValue', '0.00', 'BASE']
# ['TBillValue', '0.00', 'BASE']
# ['TBillValue', '0.00', 'EUR']
# ['TBillValue', '0.00', 'EUR']
# ['TBillValue', '0.00', 'GBP']
# ['TBillValue', '0.00', 'GBP']
# ['TBillValue', '0.00', 'HKD']
# ['TBillValue', '0.00', 'HKD']
# ['TBillValue', '0.00', 'ILS']
# ['TBillValue', '0.00', 'ILS']
# ['TBillValue', '0.00', 'JPY']
# ['TBillValue', '0.00', 'JPY']
# ['TBillValue', '0.00', 'KRW']
# ['TBillValue', '0.00', 'KRW']
# ['TBillValue', '0.00', 'NZD']
# ['TBillValue', '0.00', 'NZD']
# ['TBillValue', '0.00', 'SGD']
# ['TBillValue', '0.00', 'SGD']
# ['TBillValue', '0.00', 'TRY']
# ['TBillValue', '0.00', 'TRY']
# ['TBillValue', '0.00', 'USD']
# ['TBillValue', '0.00', 'USD']
# ['TBillValue', '0.00', 'ZAR']
# ['TBillValue', '0.00', 'ZAR']
# ['TBondValue', '0.00', 'AUD']
# ['TBondValue', '0.00', 'AUD']
# ['TBondValue', '0.00', 'BASE']
# ['TBondValue', '0.00', 'BASE']
# ['TBondValue', '0.00', 'EUR']
# ['TBondValue', '0.00', 'EUR']
# ['TBondValue', '0.00', 'GBP']
# ['TBondValue', '0.00', 'GBP']
# ['TBondValue', '0.00', 'HKD']
# ['TBondValue', '0.00', 'HKD']
# ['TBondValue', '0.00', 'ILS']
# ['TBondValue', '0.00', 'ILS']
# ['TBondValue', '0.00', 'JPY']
# ['TBondValue', '0.00', 'JPY']
# ['TBondValue', '0.00', 'KRW']
# ['TBondValue', '0.00', 'KRW']
# ['TBondValue', '0.00', 'NZD']
# ['TBondValue', '0.00', 'NZD']
# ['TBondValue', '0.00', 'SGD']
# ['TBondValue', '0.00', 'SGD']
# ['TBondValue', '0.00', 'TRY']
# ['TBondValue', '0.00', 'TRY']
# ['TBondValue', '0.00', 'USD']
# ['TBondValue', '0.00', 'USD']
# ['TBondValue', '0.00', 'ZAR']
# ['TBondValue', '0.00', 'ZAR']
# ['TotalCashBalance', '9.73', 'AUD']
# ['TotalCashBalance', '9.73', 'AUD']
# ['TotalCashBalance', '215366.5411', 'BASE']
# ['TotalCashBalance', '215366.5411', 'BASE']
# ['TotalCashBalance', '123.58', 'EUR']
# ['TotalCashBalance', '123.58', 'EUR']
# ['TotalCashBalance', '179.68', 'GBP']
# ['TotalCashBalance', '179.68', 'GBP']
# ['TotalCashBalance', '688.37', 'HKD']
# ['TotalCashBalance', '688.37', 'HKD']
# ['TotalCashBalance', '809.18', 'ILS']
# ['TotalCashBalance', '809.18', 'ILS']
# ['TotalCashBalance', '158617.66', 'JPY']
# ['TotalCashBalance', '158617.66', 'JPY']
# ['TotalCashBalance', '36631.99', 'KRW']
# ['TotalCashBalance', '36631.99', 'KRW']
# ['TotalCashBalance', '50.44', 'NZD']
# ['TotalCashBalance', '50.44', 'NZD']
# ['TotalCashBalance', '47.09', 'SGD']
# ['TotalCashBalance', '47.09', 'SGD']
# ['TotalCashBalance', '230.33', 'TRY']
# ['TotalCashBalance', '230.33', 'TRY']
# ['TotalCashBalance', '231128.72', 'USD']
# ['TotalCashBalance', '231128.72', 'USD']
# ['TotalCashBalance', '363.50', 'ZAR']
# ['TotalCashBalance', '363.50', 'ZAR']
# ['TotalCashValue', '215366.54', 'EUR']
# ['TotalCashValue', '215366.54', 'EUR']
# ['TotalCashValue-S', '215366.54', 'EUR']
# ['TotalCashValue-S', '215366.54', 'EUR']
# ['TotalDebitCardPendingCharges', '0.00', 'EUR']
# ['TotalDebitCardPendingCharges', '0.00', 'EUR']
# ['TotalDebitCardPendingCharges-S', '0.00', 'EUR']
# ['TotalDebitCardPendingCharges-S', '0.00', 'EUR']
# ['TradingType-S', 'STKNOPT', '']
# ['TradingType-S', 'STKNOPT', '']
# ['UnrealizedPnL', '0.00', 'AUD']
# ['UnrealizedPnL', '0.00', 'AUD']
# ['UnrealizedPnL', '0.00', 'BASE']
# ['UnrealizedPnL', '0.00', 'BASE']
# ['UnrealizedPnL', '0.00', 'EUR']
# ['UnrealizedPnL', '0.00', 'EUR']
# ['UnrealizedPnL', '0.00', 'GBP']
# ['UnrealizedPnL', '0.00', 'GBP']
# ['UnrealizedPnL', '0.00', 'HKD']
# ['UnrealizedPnL', '0.00', 'HKD']
# ['UnrealizedPnL', '0.00', 'ILS']
# ['UnrealizedPnL', '0.00', 'ILS']
# ['UnrealizedPnL', '0.00', 'JPY']
# ['UnrealizedPnL', '0.00', 'JPY']
# ['UnrealizedPnL', '0.00', 'KRW']
# ['UnrealizedPnL', '0.00', 'KRW']
# ['UnrealizedPnL', '0.00', 'NZD']
# ['UnrealizedPnL', '0.00', 'NZD']
# ['UnrealizedPnL', '0.00', 'SGD']
# ['UnrealizedPnL', '0.00', 'SGD']
# ['UnrealizedPnL', '0.00', 'TRY']
# ['UnrealizedPnL', '0.00', 'TRY']
# ['UnrealizedPnL', '0.00', 'USD']
# ['UnrealizedPnL', '0.00', 'USD']
# ['UnrealizedPnL', '0.00', 'ZAR']
# ['UnrealizedPnL', '0.00', 'ZAR']
# ['WarrantValue', '0.00', 'AUD']
# ['WarrantValue', '0.00', 'AUD']
# ['WarrantValue', '0.00', 'BASE']
# ['WarrantValue', '0.00', 'BASE']
# ['WarrantValue', '0.00', 'EUR']
# ['WarrantValue', '0.00', 'EUR']
# ['WarrantValue', '0.00', 'GBP']
# ['WarrantValue', '0.00', 'GBP']
# ['WarrantValue', '0.00', 'HKD']
# ['WarrantValue', '0.00', 'HKD']
# ['WarrantValue', '0.00', 'ILS']
# ['WarrantValue', '0.00', 'ILS']
# ['WarrantValue', '0.00', 'JPY']
# ['WarrantValue', '0.00', 'JPY']
# ['WarrantValue', '0.00', 'KRW']
# ['WarrantValue', '0.00', 'KRW']
# ['WarrantValue', '0.00', 'NZD']
# ['WarrantValue', '0.00', 'NZD']
# ['WarrantValue', '0.00', 'SGD']
# ['WarrantValue', '0.00', 'SGD']
# ['WarrantValue', '0.00', 'TRY']
# ['WarrantValue', '0.00', 'TRY']
# ['WarrantValue', '0.00', 'USD']
# ['WarrantValue', '0.00', 'USD']
# ['WarrantValue', '0.00', 'ZAR']
# ['WarrantValue', '0.00', 'ZAR']
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# ### getBookLivePriceAndPositions - Error while running:                      2023-08-28 08:09:36 ###
# 'DataFrame' object has no attribute 'contract'
# ### getBookLivePriceAndPositions - Done. Result:                             2023-08-28 08:09:36 ###
# None
# ####################################################################################################
# ####################################################################################################
# ### saveFXPxPositionIntoDB - Starting                                        2023-08-28 08:09:36 ###
# ### saveFXPxPositionIntoDB - Error while running:                            2023-08-28 08:09:36 ###
# [Errno 2] No such file or directory: '/home/fls/Data/Ventura/HD/Account_Data/Account/account_1_2023-08-28 07:19:47.csv'
# ### saveFXPxPositionIntoDB - Done. Result:                                   2023-08-28 08:09:36 ###
# None
# ####################################################################################################
# ####################################################################################################
# ### Script Complete - IB_Account_Data                                        2023-08-28 08:09:36 ###
# ####################################################################################################

# %%
account_id=2

# %%
getBookLivePriceAndPositions(2)
# Out:
# ####################################################################################################
# ### getBookLivePriceAndPositions - Starting                                  2023-08-28 08:11:35 ###
# ####################################################################################################
# ### Retrieving data for account 2                                            2023-08-28 08:11:35 ###
# ####################################################################################################
# IB Error  -1   2104   Market data farm connection is OK:usfarm
# IB Error  -1   2106   HMDS data farm connection is OK:cashhmds
# IB Error  -1   2106   HMDS data farm connection is OK:fundfarm
# IB Error  -1   2106   HMDS data farm connection is OK:ushmds
# IB Error  -1   2158   Sec-def data farm connection is OK:secdefnj
# ['AccountCode', 'U7336562', '']
# ['AccountCode', 'U7336562', '']
# ['AccountOrGroup', 'U7336562', 'AUD']
# ['AccountOrGroup', 'U7336562', 'AUD']
# ['AccountOrGroup', 'U7336562', 'BASE']
# ['AccountOrGroup', 'U7336562', 'BASE']
# ['AccountOrGroup', 'U7336562', 'EUR']
# ['AccountOrGroup', 'U7336562', 'EUR']
# ['AccountOrGroup', 'U7336562', 'GBP']
# ['AccountOrGroup', 'U7336562', 'GBP']
# ['AccountOrGroup', 'U7336562', 'HKD']
# ['AccountOrGroup', 'U7336562', 'HKD']
# ['AccountOrGroup', 'U7336562', 'ILS']
# ['AccountOrGroup', 'U7336562', 'ILS']
# ['AccountOrGroup', 'U7336562', 'JPY']
# ['AccountOrGroup', 'U7336562', 'JPY']
# ['AccountOrGroup', 'U7336562', 'KRW']
# ['AccountOrGroup', 'U7336562', 'KRW']
# ['AccountOrGroup', 'U7336562', 'NZD']
# ['AccountOrGroup', 'U7336562', 'NZD']
# ['AccountOrGroup', 'U7336562', 'SGD']
# ['AccountOrGroup', 'U7336562', 'SGD']
# ['AccountOrGroup', 'U7336562', 'TRY']
# ['AccountOrGroup', 'U7336562', 'TRY']
# ['AccountOrGroup', 'U7336562', 'USD']
# ['AccountOrGroup', 'U7336562', 'USD']
# ['AccountOrGroup', 'U7336562', 'ZAR']
# ['AccountOrGroup', 'U7336562', 'ZAR']
# ['AccountReady', 'true', '']
# ['AccountReady', 'true', '']
# ['AccountType', 'CORPORATION', '']
# ['AccountType', 'CORPORATION', '']
# ['AccruedCash', '0.00', 'AUD']
# ['AccruedCash', '0.00', 'AUD']
# ['AccruedCash', '651.6590859', 'BASE']
# ['AccruedCash', '651.6590859', 'BASE']
# ['AccruedCash', '651.66', 'EUR']
# ['AccruedCash', '651.66', 'EUR']
# ['AccruedCash', '0.00', 'GBP']
# ['AccruedCash', '0.00', 'GBP']
# ['AccruedCash', '0.00', 'HKD']
# ['AccruedCash', '0.00', 'HKD']
# ['AccruedCash', '0.00', 'ILS']
# ['AccruedCash', '0.00', 'ILS']
# ['AccruedCash', '-1014.00', 'JPY']
# ['AccruedCash', '-1014.00', 'JPY']
# ['AccruedCash', '0.00', 'KRW']
# ['AccruedCash', '0.00', 'KRW']
# ['AccruedCash', '0.00', 'NZD']
# ['AccruedCash', '0.00', 'NZD']
# ['AccruedCash', '0.00', 'SGD']
# ['AccruedCash', '0.00', 'SGD']
# ['AccruedCash', '0.00', 'TRY']
# ['AccruedCash', '0.00', 'TRY']
# ['AccruedCash', '711.94', 'USD']
# ['AccruedCash', '711.94', 'USD']
# ['AccruedCash', '0.00', 'ZAR']
# ['AccruedCash', '0.00', 'ZAR']
# ['AccruedCash-S', '651.66', 'EUR']
# ['AccruedCash-S', '651.66', 'EUR']
# ['AccruedDividend', '0.00', 'EUR']
# ['AccruedDividend', '0.00', 'EUR']
# ['AccruedDividend-S', '0.00', 'EUR']
# ['AccruedDividend-S', '0.00', 'EUR']
# ['AvailableFunds', '215886.59', 'EUR']
# ['AvailableFunds', '215886.59', 'EUR']
# ['AvailableFunds-S', '215886.59', 'EUR']
# ['AvailableFunds-S', '215886.59', 'EUR']
# ['Billable', '0.00', 'EUR']
# ['Billable', '0.00', 'EUR']
# ['Billable-S', '0.00', 'EUR']
# ['Billable-S', '0.00', 'EUR']
# ['BuyingPower', '1439243.91', 'EUR']
# ['BuyingPower', '1439243.91', 'EUR']
# ['CashBalance', '9.73', 'AUD']
# ['CashBalance', '9.73', 'AUD']
# ['CashBalance', '215366.5411', 'BASE']
# ['CashBalance', '215366.5411', 'BASE']
# ['CashBalance', '123.58', 'EUR']
# ['CashBalance', '123.58', 'EUR']
# ['CashBalance', '179.68', 'GBP']
# ['CashBalance', '179.68', 'GBP']
# ['CashBalance', '688.37', 'HKD']
# ['CashBalance', '688.37', 'HKD']
# ['CashBalance', '809.18', 'ILS']
# ['CashBalance', '809.18', 'ILS']
# ['CashBalance', '158617.66', 'JPY']
# ['CashBalance', '158617.66', 'JPY']
# ['CashBalance', '36631.99', 'KRW']
# ['CashBalance', '36631.99', 'KRW']
# ['CashBalance', '50.44', 'NZD']
# ['CashBalance', '50.44', 'NZD']
# ['CashBalance', '47.09', 'SGD']
# ['CashBalance', '47.09', 'SGD']
# ['CashBalance', '230.33', 'TRY']
# ['CashBalance', '230.33', 'TRY']
# ['CashBalance', '231128.72', 'USD']
# ['CashBalance', '231128.72', 'USD']
# ['CashBalance', '363.50', 'ZAR']
# ['CashBalance', '363.50', 'ZAR']
# ['ColumnPrio-S', '1', '']
# ['ColumnPrio-S', '1', '']
# ['CorporateBondValue', '0.00', 'AUD']
# ['CorporateBondValue', '0.00', 'AUD']
# ['CorporateBondValue', '0.00', 'BASE']
# ['CorporateBondValue', '0.00', 'BASE']
# ['CorporateBondValue', '0.00', 'EUR']
# ['CorporateBondValue', '0.00', 'EUR']
# ['CorporateBondValue', '0.00', 'GBP']
# ['CorporateBondValue', '0.00', 'GBP']
# ['CorporateBondValue', '0.00', 'HKD']
# ['CorporateBondValue', '0.00', 'HKD']
# ['CorporateBondValue', '0.00', 'ILS']
# ['CorporateBondValue', '0.00', 'ILS']
# ['CorporateBondValue', '0.00', 'JPY']
# ['CorporateBondValue', '0.00', 'JPY']
# ['CorporateBondValue', '0.00', 'KRW']
# ['CorporateBondValue', '0.00', 'KRW']
# ['CorporateBondValue', '0.00', 'NZD']
# ['CorporateBondValue', '0.00', 'NZD']
# ['CorporateBondValue', '0.00', 'SGD']
# ['CorporateBondValue', '0.00', 'SGD']
# ['CorporateBondValue', '0.00', 'TRY']
# ['CorporateBondValue', '0.00', 'TRY']
# ['CorporateBondValue', '0.00', 'USD']
# ['CorporateBondValue', '0.00', 'USD']
# ['CorporateBondValue', '0.00', 'ZAR']
# ['CorporateBondValue', '0.00', 'ZAR']
# ['Currency', 'AUD', 'AUD']
# ['Currency', 'AUD', 'AUD']
# ['Currency', 'BASE', 'BASE']
# ['Currency', 'BASE', 'BASE']
# ['Currency', 'EUR', 'EUR']
# ['Currency', 'EUR', 'EUR']
# ['Currency', 'GBP', 'GBP']
# ['Currency', 'GBP', 'GBP']
# ['Currency', 'HKD', 'HKD']
# ['Currency', 'HKD', 'HKD']
# ['Currency', 'ILS', 'ILS']
# ['Currency', 'ILS', 'ILS']
# ['Currency', 'JPY', 'JPY']
# ['Currency', 'JPY', 'JPY']
# ['Currency', 'KRW', 'KRW']
# ['Currency', 'KRW', 'KRW']
# ['Currency', 'NZD', 'NZD']
# ['Currency', 'NZD', 'NZD']
# ['Currency', 'SGD', 'SGD']
# ['Currency', 'SGD', 'SGD']
# ['Currency', 'TRY', 'TRY']
# ['Currency', 'TRY', 'TRY']
# ['Currency', 'USD', 'USD']
# ['Currency', 'USD', 'USD']
# ['Currency', 'ZAR', 'ZAR']
# ['Currency', 'ZAR', 'ZAR']
# ['Cushion', '1', '']
# ['Cushion', '1', '']
# ['EquityWithLoanValue', '215886.59', 'EUR']
# ['EquityWithLoanValue', '215886.59', 'EUR']
# ['EquityWithLoanValue-S', '215886.59', 'EUR']
# ['EquityWithLoanValue-S', '215886.59', 'EUR']
# ['ExcessLiquidity', '216018.20', 'EUR']
# ['ExcessLiquidity', '216018.20', 'EUR']
# ['ExcessLiquidity-S', '216018.20', 'EUR']
# ['ExcessLiquidity-S', '216018.20', 'EUR']
# ['ExchangeRate', '0.5947727', 'AUD']
# ['ExchangeRate', '0.5947727', 'AUD']
# ['ExchangeRate', '1.00', 'BASE']
# ['ExchangeRate', '1.00', 'BASE']
# ['ExchangeRate', '1.00', 'EUR']
# ['ExchangeRate', '1.00', 'EUR']
# ['ExchangeRate', '1.1657453', 'GBP']
# ['ExchangeRate', '1.1657453', 'GBP']
# ['ExchangeRate', '0.1179425', 'HKD']
# ['ExchangeRate', '0.1179425', 'HKD']
# ['ExchangeRate', '0.2439425', 'ILS']
# ['ExchangeRate', '0.2439425', 'ILS']
# ['ExchangeRate', '0.0063155', 'JPY']
# ['ExchangeRate', '0.0063155', 'JPY']
# ['ExchangeRate', '0.0006984', 'KRW']
# ['ExchangeRate', '0.0006984', 'KRW']
# ['ExchangeRate', '0.5473112', 'NZD']
# ['ExchangeRate', '0.5473112', 'NZD']
# ['ExchangeRate', '0.6823715', 'SGD']
# ['ExchangeRate', '0.6823715', 'SGD']
# ['ExchangeRate', '0.0349315', 'TRY']
# ['ExchangeRate', '0.0349315', 'TRY']
# ['ExchangeRate', '0.9251763', 'USD']
# ['ExchangeRate', '0.9251763', 'USD']
# ['ExchangeRate', '0.0497201', 'ZAR']
# ['ExchangeRate', '0.0497201', 'ZAR']
# ['FullAvailableFunds', '215886.59', 'EUR']
# ['FullAvailableFunds', '215886.59', 'EUR']
# ['FullAvailableFunds-S', '215886.59', 'EUR']
# ['FullAvailableFunds-S', '215886.59', 'EUR']
# ['FullExcessLiquidity', '216018.20', 'EUR']
# ['FullExcessLiquidity', '216018.20', 'EUR']
# ['FullExcessLiquidity-S', '216018.20', 'EUR']
# ['FullExcessLiquidity-S', '216018.20', 'EUR']
# ['FullInitMarginReq', '0.00', 'EUR']
# ['FullInitMarginReq', '0.00', 'EUR']
# ['FullInitMarginReq-S', '0.00', 'EUR']
# ['FullInitMarginReq-S', '0.00', 'EUR']
# ['FullMaintMarginReq', '0.00', 'EUR']
# ['FullMaintMarginReq', '0.00', 'EUR']
# ['FullMaintMarginReq-S', '0.00', 'EUR']
# ['FullMaintMarginReq-S', '0.00', 'EUR']
# ['FundValue', '0.00', 'AUD']
# ['FundValue', '0.00', 'AUD']
# ['FundValue', '0.00', 'BASE']
# ['FundValue', '0.00', 'BASE']
# ['FundValue', '0.00', 'EUR']
# ['FundValue', '0.00', 'EUR']
# ['FundValue', '0.00', 'GBP']
# ['FundValue', '0.00', 'GBP']
# ['FundValue', '0.00', 'HKD']
# ['FundValue', '0.00', 'HKD']
# ['FundValue', '0.00', 'ILS']
# ['FundValue', '0.00', 'ILS']
# ['FundValue', '0.00', 'JPY']
# ['FundValue', '0.00', 'JPY']
# ['FundValue', '0.00', 'KRW']
# ['FundValue', '0.00', 'KRW']
# ['FundValue', '0.00', 'NZD']
# ['FundValue', '0.00', 'NZD']
# ['FundValue', '0.00', 'SGD']
# ['FundValue', '0.00', 'SGD']
# ['FundValue', '0.00', 'TRY']
# ['FundValue', '0.00', 'TRY']
# ['FundValue', '0.00', 'USD']
# ['FundValue', '0.00', 'USD']
# ['FundValue', '0.00', 'ZAR']
# ['FundValue', '0.00', 'ZAR']
# ['FutureOptionValue', '0.00', 'AUD']
# ['FutureOptionValue', '0.00', 'AUD']
# ['FutureOptionValue', '0.00', 'BASE']
# ['FutureOptionValue', '0.00', 'BASE']
# ['FutureOptionValue', '0.00', 'EUR']
# ['FutureOptionValue', '0.00', 'EUR']
# ['FutureOptionValue', '0.00', 'GBP']
# ['FutureOptionValue', '0.00', 'GBP']
# ['FutureOptionValue', '0.00', 'HKD']
# ['FutureOptionValue', '0.00', 'HKD']
# ['FutureOptionValue', '0.00', 'ILS']
# ['FutureOptionValue', '0.00', 'ILS']
# ['FutureOptionValue', '0.00', 'JPY']
# ['FutureOptionValue', '0.00', 'JPY']
# ['FutureOptionValue', '0.00', 'KRW']
# ['FutureOptionValue', '0.00', 'KRW']
# ['FutureOptionValue', '0.00', 'NZD']
# ['FutureOptionValue', '0.00', 'NZD']
# ['FutureOptionValue', '0.00', 'SGD']
# ['FutureOptionValue', '0.00', 'SGD']
# ['FutureOptionValue', '0.00', 'TRY']
# ['FutureOptionValue', '0.00', 'TRY']
# ['FutureOptionValue', '0.00', 'USD']
# ['FutureOptionValue', '0.00', 'USD']
# ['FutureOptionValue', '0.00', 'ZAR']
# ['FutureOptionValue', '0.00', 'ZAR']
# ['FuturesPNL', '0.00', 'AUD']
# ['FuturesPNL', '0.00', 'AUD']
# ['FuturesPNL', '0.00', 'BASE']
# ['FuturesPNL', '0.00', 'BASE']
# ['FuturesPNL', '0.00', 'EUR']
# ['FuturesPNL', '0.00', 'EUR']
# ['FuturesPNL', '0.00', 'GBP']
# ['FuturesPNL', '0.00', 'GBP']
# ['FuturesPNL', '0.00', 'HKD']
# ['FuturesPNL', '0.00', 'HKD']
# ['FuturesPNL', '0.00', 'ILS']
# ['FuturesPNL', '0.00', 'ILS']
# ['FuturesPNL', '0.00', 'JPY']
# ['FuturesPNL', '0.00', 'JPY']
# ['FuturesPNL', '0.00', 'KRW']
# ['FuturesPNL', '0.00', 'KRW']
# ['FuturesPNL', '0.00', 'NZD']
# ['FuturesPNL', '0.00', 'NZD']
# ['FuturesPNL', '0.00', 'SGD']
# ['FuturesPNL', '0.00', 'SGD']
# ['FuturesPNL', '0.00', 'TRY']
# ['FuturesPNL', '0.00', 'TRY']
# ['FuturesPNL', '0.00', 'USD']
# ['FuturesPNL', '0.00', 'USD']
# ['FuturesPNL', '0.00', 'ZAR']
# ['FuturesPNL', '0.00', 'ZAR']
# ['FxCashBalance', '0.00', 'AUD']
# ['FxCashBalance', '0.00', 'AUD']
# ['FxCashBalance', '0.00', 'BASE']
# ['FxCashBalance', '0.00', 'BASE']
# ['FxCashBalance', '0.00', 'EUR']
# ['FxCashBalance', '0.00', 'EUR']
# ['FxCashBalance', '0.00', 'GBP']
# ['FxCashBalance', '0.00', 'GBP']
# ['FxCashBalance', '0.00', 'HKD']
# ['FxCashBalance', '0.00', 'HKD']
# ['FxCashBalance', '0.00', 'ILS']
# ['FxCashBalance', '0.00', 'ILS']
# ['FxCashBalance', '0.00', 'JPY']
# ['FxCashBalance', '0.00', 'JPY']
# ['FxCashBalance', '0.00', 'KRW']
# ['FxCashBalance', '0.00', 'KRW']
# ['FxCashBalance', '0.00', 'NZD']
# ['FxCashBalance', '0.00', 'NZD']
# ['FxCashBalance', '0.00', 'SGD']
# ['FxCashBalance', '0.00', 'SGD']
# ['FxCashBalance', '0.00', 'TRY']
# ['FxCashBalance', '0.00', 'TRY']
# ['FxCashBalance', '0.00', 'USD']
# ['FxCashBalance', '0.00', 'USD']
# ['FxCashBalance', '0.00', 'ZAR']
# ['FxCashBalance', '0.00', 'ZAR']
# ['GrossPositionValue', '0.00', 'EUR']
# ['GrossPositionValue', '0.00', 'EUR']
# ['GrossPositionValue-S', '0.00', 'EUR']
# ['GrossPositionValue-S', '0.00', 'EUR']
# ['Guarantee', '0.00', 'EUR']
# ['Guarantee', '0.00', 'EUR']
# ['Guarantee-S', '0.00', 'EUR']
# ['Guarantee-S', '0.00', 'EUR']
# ['IndianStockHaircut', '0.00', 'EUR']
# ['IndianStockHaircut', '0.00', 'EUR']
# ['IndianStockHaircut-S', '0.00', 'EUR']
# ['IndianStockHaircut-S', '0.00', 'EUR']
# ['InitMarginReq', '0.00', 'EUR']
# ['InitMarginReq', '0.00', 'EUR']
# ['InitMarginReq-S', '0.00', 'EUR']
# ['InitMarginReq-S', '0.00', 'EUR']
# ['IssuerOptionValue', '0.00', 'AUD']
# ['IssuerOptionValue', '0.00', 'AUD']
# ['IssuerOptionValue', '0.00', 'BASE']
# ['IssuerOptionValue', '0.00', 'BASE']
# ['IssuerOptionValue', '0.00', 'EUR']
# ['IssuerOptionValue', '0.00', 'EUR']
# ['IssuerOptionValue', '0.00', 'GBP']
# ['IssuerOptionValue', '0.00', 'GBP']
# ['IssuerOptionValue', '0.00', 'HKD']
# ['IssuerOptionValue', '0.00', 'HKD']
# ['IssuerOptionValue', '0.00', 'ILS']
# ['IssuerOptionValue', '0.00', 'ILS']
# ['IssuerOptionValue', '0.00', 'JPY']
# ['IssuerOptionValue', '0.00', 'JPY']
# ['IssuerOptionValue', '0.00', 'KRW']
# ['IssuerOptionValue', '0.00', 'KRW']
# ['IssuerOptionValue', '0.00', 'NZD']
# ['IssuerOptionValue', '0.00', 'NZD']
# ['IssuerOptionValue', '0.00', 'SGD']
# ['IssuerOptionValue', '0.00', 'SGD']
# ['IssuerOptionValue', '0.00', 'TRY']
# ['IssuerOptionValue', '0.00', 'TRY']
# ['IssuerOptionValue', '0.00', 'USD']
# ['IssuerOptionValue', '0.00', 'USD']
# ['IssuerOptionValue', '0.00', 'ZAR']
# ['IssuerOptionValue', '0.00', 'ZAR']
# ['Leverage-S', '0.00', '']
# ['Leverage-S', '0.00', '']
# ['LookAheadAvailableFunds', '215886.59', 'EUR']
# ['LookAheadAvailableFunds', '215886.59', 'EUR']
# ['LookAheadAvailableFunds-S', '215886.59', 'EUR']
# ['LookAheadAvailableFunds-S', '215886.59', 'EUR']
# ['LookAheadExcessLiquidity', '216018.20', 'EUR']
# ['LookAheadExcessLiquidity', '216018.20', 'EUR']
# ['LookAheadExcessLiquidity-S', '216018.20', 'EUR']
# ['LookAheadExcessLiquidity-S', '216018.20', 'EUR']
# ['LookAheadInitMarginReq', '0.00', 'EUR']
# ['LookAheadInitMarginReq', '0.00', 'EUR']
# ['LookAheadInitMarginReq-S', '0.00', 'EUR']
# ['LookAheadInitMarginReq-S', '0.00', 'EUR']
# ['LookAheadMaintMarginReq', '0.00', 'EUR']
# ['LookAheadMaintMarginReq', '0.00', 'EUR']
# ['LookAheadMaintMarginReq-S', '0.00', 'EUR']
# ['LookAheadMaintMarginReq-S', '0.00', 'EUR']
# ['LookAheadNextChange', '0', '']
# ['LookAheadNextChange', '0', '']
# ['MaintMarginReq', '0.00', 'EUR']
# ['MaintMarginReq', '0.00', 'EUR']
# ['MaintMarginReq-S', '0.00', 'EUR']
# ['MaintMarginReq-S', '0.00', 'EUR']
# ['MoneyMarketFundValue', '0.00', 'AUD']
# ['MoneyMarketFundValue', '0.00', 'AUD']
# ['MoneyMarketFundValue', '0.00', 'BASE']
# ['MoneyMarketFundValue', '0.00', 'BASE']
# ['MoneyMarketFundValue', '0.00', 'EUR']
# ['MoneyMarketFundValue', '0.00', 'EUR']
# ['MoneyMarketFundValue', '0.00', 'GBP']
# ['MoneyMarketFundValue', '0.00', 'GBP']
# ['MoneyMarketFundValue', '0.00', 'HKD']
# ['MoneyMarketFundValue', '0.00', 'HKD']
# ['MoneyMarketFundValue', '0.00', 'ILS']
# ['MoneyMarketFundValue', '0.00', 'ILS']
# ['MoneyMarketFundValue', '0.00', 'JPY']
# ['MoneyMarketFundValue', '0.00', 'JPY']
# ['MoneyMarketFundValue', '0.00', 'KRW']
# ['MoneyMarketFundValue', '0.00', 'KRW']
# ['MoneyMarketFundValue', '0.00', 'NZD']
# ['MoneyMarketFundValue', '0.00', 'NZD']
# ['MoneyMarketFundValue', '0.00', 'SGD']
# ['MoneyMarketFundValue', '0.00', 'SGD']
# ['MoneyMarketFundValue', '0.00', 'TRY']
# ['MoneyMarketFundValue', '0.00', 'TRY']
# ['MoneyMarketFundValue', '0.00', 'USD']
# ['MoneyMarketFundValue', '0.00', 'USD']
# ['MoneyMarketFundValue', '0.00', 'ZAR']
# ['MoneyMarketFundValue', '0.00', 'ZAR']
# ['MutualFundValue', '0.00', 'AUD']
# ['MutualFundValue', '0.00', 'AUD']
# ['MutualFundValue', '0.00', 'BASE']
# ['MutualFundValue', '0.00', 'BASE']
# ['MutualFundValue', '0.00', 'EUR']
# ['MutualFundValue', '0.00', 'EUR']
# ['MutualFundValue', '0.00', 'GBP']
# ['MutualFundValue', '0.00', 'GBP']
# ['MutualFundValue', '0.00', 'HKD']
# ['MutualFundValue', '0.00', 'HKD']
# ['MutualFundValue', '0.00', 'ILS']
# ['MutualFundValue', '0.00', 'ILS']
# ['MutualFundValue', '0.00', 'JPY']
# ['MutualFundValue', '0.00', 'JPY']
# ['MutualFundValue', '0.00', 'KRW']
# ['MutualFundValue', '0.00', 'KRW']
# ['MutualFundValue', '0.00', 'NZD']
# ['MutualFundValue', '0.00', 'NZD']
# ['MutualFundValue', '0.00', 'SGD']
# ['MutualFundValue', '0.00', 'SGD']
# ['MutualFundValue', '0.00', 'TRY']
# ['MutualFundValue', '0.00', 'TRY']
# ['MutualFundValue', '0.00', 'USD']
# ['MutualFundValue', '0.00', 'USD']
# ['MutualFundValue', '0.00', 'ZAR']
# ['MutualFundValue', '0.00', 'ZAR']
# ['NLVAndMarginInReview', 'false', '']
# ['NLVAndMarginInReview', 'false', '']
# ['NetDividend', '0.00', 'AUD']
# ['NetDividend', '0.00', 'AUD']
# ['NetDividend', '0.00', 'BASE']
# ['NetDividend', '0.00', 'BASE']
# ['NetDividend', '0.00', 'EUR']
# ['NetDividend', '0.00', 'EUR']
# ['NetDividend', '0.00', 'GBP']
# ['NetDividend', '0.00', 'GBP']
# ['NetDividend', '0.00', 'HKD']
# ['NetDividend', '0.00', 'HKD']
# ['NetDividend', '0.00', 'ILS']
# ['NetDividend', '0.00', 'ILS']
# ['NetDividend', '0.00', 'JPY']
# ['NetDividend', '0.00', 'JPY']
# ['NetDividend', '0.00', 'KRW']
# ['NetDividend', '0.00', 'KRW']
# ['NetDividend', '0.00', 'NZD']
# ['NetDividend', '0.00', 'NZD']
# ['NetDividend', '0.00', 'SGD']
# ['NetDividend', '0.00', 'SGD']
# ['NetDividend', '0.00', 'TRY']
# ['NetDividend', '0.00', 'TRY']
# ['NetDividend', '0.00', 'USD']
# ['NetDividend', '0.00', 'USD']
# ['NetDividend', '0.00', 'ZAR']
# ['NetDividend', '0.00', 'ZAR']
# ['NetLiquidation', '216018.20', 'EUR']
# ['NetLiquidation', '216018.20', 'EUR']
# ['NetLiquidation-S', '216018.20', 'EUR']
# ['NetLiquidation-S', '216018.20', 'EUR']
# ['NetLiquidationByCurrency', '9.73', 'AUD']
# ['NetLiquidationByCurrency', '9.73', 'AUD']
# ['NetLiquidationByCurrency', '216018.2002', 'BASE']
# ['NetLiquidationByCurrency', '216018.2002', 'BASE']
# ['NetLiquidationByCurrency', '123.58', 'EUR']
# ['NetLiquidationByCurrency', '123.58', 'EUR']
# ['NetLiquidationByCurrency', '179.68', 'GBP']
# ['NetLiquidationByCurrency', '179.68', 'GBP']
# ['NetLiquidationByCurrency', '688.37', 'HKD']
# ['NetLiquidationByCurrency', '688.37', 'HKD']
# ['NetLiquidationByCurrency', '809.18', 'ILS']
# ['NetLiquidationByCurrency', '809.18', 'ILS']
# ['NetLiquidationByCurrency', '157603.66', 'JPY']
# ['NetLiquidationByCurrency', '157603.66', 'JPY']
# ['NetLiquidationByCurrency', '36631.99', 'KRW']
# ['NetLiquidationByCurrency', '36631.99', 'KRW']
# ['NetLiquidationByCurrency', '50.44', 'NZD']
# ['NetLiquidationByCurrency', '50.44', 'NZD']
# ['NetLiquidationByCurrency', '47.09', 'SGD']
# ['NetLiquidationByCurrency', '47.09', 'SGD']
# ['NetLiquidationByCurrency', '230.33', 'TRY']
# ['NetLiquidationByCurrency', '230.33', 'TRY']
# ['NetLiquidationByCurrency', '231840.66', 'USD']
# ['NetLiquidationByCurrency', '231840.66', 'USD']
# ['NetLiquidationByCurrency', '363.50', 'ZAR']
# ['NetLiquidationByCurrency', '363.50', 'ZAR']
# ['NetLiquidationUncertainty', '0.00', 'EUR']
# ['NetLiquidationUncertainty', '0.00', 'EUR']
# ['OptionMarketValue', '0.00', 'AUD']
# ['OptionMarketValue', '0.00', 'AUD']
# ['OptionMarketValue', '0.00', 'BASE']
# ['OptionMarketValue', '0.00', 'BASE']
# ['OptionMarketValue', '0.00', 'EUR']
# ['OptionMarketValue', '0.00', 'EUR']
# ['OptionMarketValue', '0.00', 'GBP']
# ['OptionMarketValue', '0.00', 'GBP']
# ['OptionMarketValue', '0.00', 'HKD']
# ['OptionMarketValue', '0.00', 'HKD']
# ['OptionMarketValue', '0.00', 'ILS']
# ['OptionMarketValue', '0.00', 'ILS']
# ['OptionMarketValue', '0.00', 'JPY']
# ['OptionMarketValue', '0.00', 'JPY']
# ['OptionMarketValue', '0.00', 'KRW']
# ['OptionMarketValue', '0.00', 'KRW']
# ['OptionMarketValue', '0.00', 'NZD']
# ['OptionMarketValue', '0.00', 'NZD']
# ['OptionMarketValue', '0.00', 'SGD']
# ['OptionMarketValue', '0.00', 'SGD']
# ['OptionMarketValue', '0.00', 'TRY']
# ['OptionMarketValue', '0.00', 'TRY']
# ['OptionMarketValue', '0.00', 'USD']
# ['OptionMarketValue', '0.00', 'USD']
# ['OptionMarketValue', '0.00', 'ZAR']
# ['OptionMarketValue', '0.00', 'ZAR']
# ['PASharesValue', '0.00', 'EUR']
# ['PASharesValue', '0.00', 'EUR']
# ['PASharesValue-S', '0.00', 'EUR']
# ['PASharesValue-S', '0.00', 'EUR']
# ['PhysicalCertificateValue', '0.00', 'EUR']
# ['PhysicalCertificateValue', '0.00', 'EUR']
# ['PhysicalCertificateValue-S', '0.00', 'EUR']
# ['PhysicalCertificateValue-S', '0.00', 'EUR']
# ['PostExpirationExcess', '0.00', 'EUR']
# ['PostExpirationExcess', '0.00', 'EUR']
# ['PostExpirationExcess-S', '0.00', 'EUR']
# ['PostExpirationExcess-S', '0.00', 'EUR']
# ['PostExpirationMargin', '0.00', 'EUR']
# ['PostExpirationMargin', '0.00', 'EUR']
# ['PostExpirationMargin-S', '0.00', 'EUR']
# ['PostExpirationMargin-S', '0.00', 'EUR']
# ['RealCurrency', 'AUD', 'AUD']
# ['RealCurrency', 'AUD', 'AUD']
# ['RealCurrency', 'BASE', 'BASE']
# ['RealCurrency', 'BASE', 'BASE']
# ['RealCurrency', 'EUR', 'EUR']
# ['RealCurrency', 'EUR', 'EUR']
# ['RealCurrency', 'GBP', 'GBP']
# ['RealCurrency', 'GBP', 'GBP']
# ['RealCurrency', 'HKD', 'HKD']
# ['RealCurrency', 'HKD', 'HKD']
# ['RealCurrency', 'ILS', 'ILS']
# ['RealCurrency', 'ILS', 'ILS']
# ['RealCurrency', 'JPY', 'JPY']
# ['RealCurrency', 'JPY', 'JPY']
# ['RealCurrency', 'KRW', 'KRW']
# ['RealCurrency', 'KRW', 'KRW']
# ['RealCurrency', 'NZD', 'NZD']
# ['RealCurrency', 'NZD', 'NZD']
# ['RealCurrency', 'SGD', 'SGD']
# ['RealCurrency', 'SGD', 'SGD']
# ['RealCurrency', 'TRY', 'TRY']
# ['RealCurrency', 'TRY', 'TRY']
# ['RealCurrency', 'USD', 'USD']
# ['RealCurrency', 'USD', 'USD']
# ['RealCurrency', 'ZAR', 'ZAR']
# ['RealCurrency', 'ZAR', 'ZAR']
# ['RealizedPnL', '0.00', 'AUD']
# ['RealizedPnL', '0.00', 'AUD']
# ['RealizedPnL', '0.00', 'BASE']
# ['RealizedPnL', '0.00', 'BASE']
# ['RealizedPnL', '0.00', 'EUR']
# ['RealizedPnL', '0.00', 'EUR']
# ['RealizedPnL', '0.00', 'GBP']
# ['RealizedPnL', '0.00', 'GBP']
# ['RealizedPnL', '0.00', 'HKD']
# ['RealizedPnL', '0.00', 'HKD']
# ['RealizedPnL', '0.00', 'ILS']
# ['RealizedPnL', '0.00', 'ILS']
# ['RealizedPnL', '0.00', 'JPY']
# ['RealizedPnL', '0.00', 'JPY']
# ['RealizedPnL', '0.00', 'KRW']
# ['RealizedPnL', '0.00', 'KRW']
# ['RealizedPnL', '0.00', 'NZD']
# ['RealizedPnL', '0.00', 'NZD']
# ['RealizedPnL', '0.00', 'SGD']
# ['RealizedPnL', '0.00', 'SGD']
# ['RealizedPnL', '0.00', 'TRY']
# ['RealizedPnL', '0.00', 'TRY']
# ['RealizedPnL', '0.00', 'USD']
# ['RealizedPnL', '0.00', 'USD']
# ['RealizedPnL', '0.00', 'ZAR']
# ['RealizedPnL', '0.00', 'ZAR']
# ['SegmentTitle-S', 'Securities', '']
# ['SegmentTitle-S', 'Securities', '']
# ['StockMarketValue', '0.00', 'AUD']
# ['StockMarketValue', '0.00', 'AUD']
# ['StockMarketValue', '0.00', 'BASE']
# ['StockMarketValue', '0.00', 'BASE']
# ['StockMarketValue', '0.00', 'EUR']
# ['StockMarketValue', '0.00', 'EUR']
# ['StockMarketValue', '0.00', 'GBP']
# ['StockMarketValue', '0.00', 'GBP']
# ['StockMarketValue', '0.00', 'HKD']
# ['StockMarketValue', '0.00', 'HKD']
# ['StockMarketValue', '0.00', 'ILS']
# ['StockMarketValue', '0.00', 'ILS']
# ['StockMarketValue', '0.00', 'JPY']
# ['StockMarketValue', '0.00', 'JPY']
# ['StockMarketValue', '0.00', 'KRW']
# ['StockMarketValue', '0.00', 'KRW']
# ['StockMarketValue', '0.00', 'NZD']
# ['StockMarketValue', '0.00', 'NZD']
# ['StockMarketValue', '0.00', 'SGD']
# ['StockMarketValue', '0.00', 'SGD']
# ['StockMarketValue', '0.00', 'TRY']
# ['StockMarketValue', '0.00', 'TRY']
# ['StockMarketValue', '0.00', 'USD']
# ['StockMarketValue', '0.00', 'USD']
# ['StockMarketValue', '0.00', 'ZAR']
# ['StockMarketValue', '0.00', 'ZAR']
# ['TBillValue', '0.00', 'AUD']
# ['TBillValue', '0.00', 'AUD']
# ['TBillValue', '0.00', 'BASE']
# ['TBillValue', '0.00', 'BASE']
# ['TBillValue', '0.00', 'EUR']
# ['TBillValue', '0.00', 'EUR']
# ['TBillValue', '0.00', 'GBP']
# ['TBillValue', '0.00', 'GBP']
# ['TBillValue', '0.00', 'HKD']
# ['TBillValue', '0.00', 'HKD']
# ['TBillValue', '0.00', 'ILS']
# ['TBillValue', '0.00', 'ILS']
# ['TBillValue', '0.00', 'JPY']
# ['TBillValue', '0.00', 'JPY']
# ['TBillValue', '0.00', 'KRW']
# ['TBillValue', '0.00', 'KRW']
# ['TBillValue', '0.00', 'NZD']
# ['TBillValue', '0.00', 'NZD']
# ['TBillValue', '0.00', 'SGD']
# ['TBillValue', '0.00', 'SGD']
# ['TBillValue', '0.00', 'TRY']
# ['TBillValue', '0.00', 'TRY']
# ['TBillValue', '0.00', 'USD']
# ['TBillValue', '0.00', 'USD']
# ['TBillValue', '0.00', 'ZAR']
# ['TBillValue', '0.00', 'ZAR']
# ['TBondValue', '0.00', 'AUD']
# ['TBondValue', '0.00', 'AUD']
# ['TBondValue', '0.00', 'BASE']
# ['TBondValue', '0.00', 'BASE']
# ['TBondValue', '0.00', 'EUR']
# ['TBondValue', '0.00', 'EUR']
# ['TBondValue', '0.00', 'GBP']
# ['TBondValue', '0.00', 'GBP']
# ['TBondValue', '0.00', 'HKD']
# ['TBondValue', '0.00', 'HKD']
# ['TBondValue', '0.00', 'ILS']
# ['TBondValue', '0.00', 'ILS']
# ['TBondValue', '0.00', 'JPY']
# ['TBondValue', '0.00', 'JPY']
# ['TBondValue', '0.00', 'KRW']
# ['TBondValue', '0.00', 'KRW']
# ['TBondValue', '0.00', 'NZD']
# ['TBondValue', '0.00', 'NZD']
# ['TBondValue', '0.00', 'SGD']
# ['TBondValue', '0.00', 'SGD']
# ['TBondValue', '0.00', 'TRY']
# ['TBondValue', '0.00', 'TRY']
# ['TBondValue', '0.00', 'USD']
# ['TBondValue', '0.00', 'USD']
# ['TBondValue', '0.00', 'ZAR']
# ['TBondValue', '0.00', 'ZAR']
# ['TotalCashBalance', '9.73', 'AUD']
# ['TotalCashBalance', '9.73', 'AUD']
# ['TotalCashBalance', '215366.5411', 'BASE']
# ['TotalCashBalance', '215366.5411', 'BASE']
# ['TotalCashBalance', '123.58', 'EUR']
# ['TotalCashBalance', '123.58', 'EUR']
# ['TotalCashBalance', '179.68', 'GBP']
# ['TotalCashBalance', '179.68', 'GBP']
# ['TotalCashBalance', '688.37', 'HKD']
# ['TotalCashBalance', '688.37', 'HKD']
# ['TotalCashBalance', '809.18', 'ILS']
# ['TotalCashBalance', '809.18', 'ILS']
# ['TotalCashBalance', '158617.66', 'JPY']
# ['TotalCashBalance', '158617.66', 'JPY']
# ['TotalCashBalance', '36631.99', 'KRW']
# ['TotalCashBalance', '36631.99', 'KRW']
# ['TotalCashBalance', '50.44', 'NZD']
# ['TotalCashBalance', '50.44', 'NZD']
# ['TotalCashBalance', '47.09', 'SGD']
# ['TotalCashBalance', '47.09', 'SGD']
# ['TotalCashBalance', '230.33', 'TRY']
# ['TotalCashBalance', '230.33', 'TRY']
# ['TotalCashBalance', '231128.72', 'USD']
# ['TotalCashBalance', '231128.72', 'USD']
# ['TotalCashBalance', '363.50', 'ZAR']
# ['TotalCashBalance', '363.50', 'ZAR']
# ['TotalCashValue', '215366.54', 'EUR']
# ['TotalCashValue', '215366.54', 'EUR']
# ['TotalCashValue-S', '215366.54', 'EUR']
# ['TotalCashValue-S', '215366.54', 'EUR']
# ['TotalDebitCardPendingCharges', '0.00', 'EUR']
# ['TotalDebitCardPendingCharges', '0.00', 'EUR']
# ['TotalDebitCardPendingCharges-S', '0.00', 'EUR']
# ['TotalDebitCardPendingCharges-S', '0.00', 'EUR']
# ['TradingType-S', 'STKNOPT', '']
# ['TradingType-S', 'STKNOPT', '']
# ['UnrealizedPnL', '0.00', 'AUD']
# ['UnrealizedPnL', '0.00', 'AUD']
# ['UnrealizedPnL', '0.00', 'BASE']
# ['UnrealizedPnL', '0.00', 'BASE']
# ['UnrealizedPnL', '0.00', 'EUR']
# ['UnrealizedPnL', '0.00', 'EUR']
# ['UnrealizedPnL', '0.00', 'GBP']
# ['UnrealizedPnL', '0.00', 'GBP']
# ['UnrealizedPnL', '0.00', 'HKD']
# ['UnrealizedPnL', '0.00', 'HKD']
# ['UnrealizedPnL', '0.00', 'ILS']
# ['UnrealizedPnL', '0.00', 'ILS']
# ['UnrealizedPnL', '0.00', 'JPY']
# ['UnrealizedPnL', '0.00', 'JPY']
# ['UnrealizedPnL', '0.00', 'KRW']
# ['UnrealizedPnL', '0.00', 'KRW']
# ['UnrealizedPnL', '0.00', 'NZD']
# ['UnrealizedPnL', '0.00', 'NZD']
# ['UnrealizedPnL', '0.00', 'SGD']
# ['UnrealizedPnL', '0.00', 'SGD']
# ['UnrealizedPnL', '0.00', 'TRY']
# ['UnrealizedPnL', '0.00', 'TRY']
# ['UnrealizedPnL', '0.00', 'USD']
# ['UnrealizedPnL', '0.00', 'USD']
# ['UnrealizedPnL', '0.00', 'ZAR']
# ['UnrealizedPnL', '0.00', 'ZAR']
# ['WarrantValue', '0.00', 'AUD']
# ['WarrantValue', '0.00', 'AUD']
# ['WarrantValue', '0.00', 'BASE']
# ['WarrantValue', '0.00', 'BASE']
# ['WarrantValue', '0.00', 'EUR']
# ['WarrantValue', '0.00', 'EUR']
# ['WarrantValue', '0.00', 'GBP']
# ['WarrantValue', '0.00', 'GBP']
# ['WarrantValue', '0.00', 'HKD']
# ['WarrantValue', '0.00', 'HKD']
# ['WarrantValue', '0.00', 'ILS']
# ['WarrantValue', '0.00', 'ILS']
# ['WarrantValue', '0.00', 'JPY']
# ['WarrantValue', '0.00', 'JPY']
# ['WarrantValue', '0.00', 'KRW']
# ['WarrantValue', '0.00', 'KRW']
# ['WarrantValue', '0.00', 'NZD']
# ['WarrantValue', '0.00', 'NZD']
# ['WarrantValue', '0.00', 'SGD']
# ['WarrantValue', '0.00', 'SGD']
# ['WarrantValue', '0.00', 'TRY']
# ['WarrantValue', '0.00', 'TRY']
# ['WarrantValue', '0.00', 'USD']
# ['WarrantValue', '0.00', 'USD']
# ['WarrantValue', '0.00', 'ZAR']
# ['WarrantValue', '0.00', 'ZAR']
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# ### getBookLivePriceAndPositions - Error while running:                      2023-08-28 08:11:36 ###
# 'DataFrame' object has no attribute 'contract'
# ### getBookLivePriceAndPositions - Done. Result:                             2023-08-28 08:11:36 ###
# None
# ####################################################################################################

# %%
ib_app = IBAppBook()
ib_port = xu.getIBPort(account_id)

# %%
ib_port
# Out:
# 7499

# %%
script_name
# Out:
# 'IB_Account_Data'

# %%
ib_client_id = xu.getIBClientId(script_name)

# %%
ib_client_id
# Out:
# 123

# %%
ib_app.connect("127.0.0.1", ib_port, ib_client_id)

# %%
ib_app.account_id = account_id

# %%
ib_app.run()
# Out:
# Start
# start
# IB Error  -1   2104   Market data farm connection is OK:usfarm
# IB Error  -1   2106   HMDS data farm connection is OK:cashhmds
# IB Error  -1   2106   HMDS data farm connection is OK:fundfarm
# IB Error  -1   2106   HMDS data farm connection is OK:ushmds
# IB Error  -1   2158   Sec-def data farm connection is OK:secdefnj
# accountDownloadEnd
# finalFormatting
# Empty DataFrame
# Columns: []
# Index: []
# stop

# %%
from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract
from threading import Timer

class TestApp(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)

    def error(self, reqId, errorCode, errorString):
        print("Error: ", reqId, " ", errorCode, " ", errorString)

    def nextValidId(self, orderId):
        self.start()

    def updatePortfolio(self, contract: Contract, position: float, marketPrice: float, marketValue: float,
                        averageCost: float, unrealizedPNL: float, realizedPNL: float, accountName: str):
        print("UpdatePortfolio.", "Symbol:", contract.symbol, "SecType:", contract.secType, "Exchange:", contract.exchange,
              "Position:", position, "MarketPrice:", marketPrice, "MarketValue:", marketValue, "AverageCost:", averageCost,
              "UnrealizedPNL:", unrealizedPNL, "RealizedPNL:", realizedPNL, "AccountName:", accountName)

    def updateAccountValue(self, key: str, val: str, currency: str, accountName: str):
        print("UpdateAccountValue. Key:", key, "Value:", val, "Currency:", currency, "AccountName:", accountName)

    def updateAccountTime(self, timeStamp: str):
        print("UpdateAccountTime. Time:", timeStamp)

    def accountDownloadEnd(self, accountName: str):
        print("AccountDownloadEnd. Account:", accountName)

    def start(self):
        # Account number can be omitted when using reqAccountUpdates with single account structure
        self.reqAccountUpdates(True, "")

    def stop(self):
        self.reqAccountUpdates(False, "")
        self.done = True
        self.disconnect()

def main():
    app = TestApp()
    app.connect("127.0.0.1", 7499, 0)

    Timer(5, app.stop).start()
    app.run()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 48
#      45     app.run()
#      47 if __name__ == "__main__":
# ---> 48     main()
#
# Cell In[47], line 45, in main()
#      42 app.connect("127.0.0.1", 7499, 0)
#      44 Timer(5, app.stop).start()
# ---> 45 app.run()
#
# File ~/anaconda3/lib/python3.8/site-packages/ibapi-10.22.1-py3.8.egg/ibapi/client.py:263, in EClient.run(self)
#     261         fields = comm.read_fields(text)
#     262         logger.debug("fields %s", fields)
# --> 263         self.decoder.interpret(fields)
#     264         self.msgLoopRec()
#     265 except (KeyboardInterrupt, SystemExit):
#
# File ~/anaconda3/lib/python3.8/site-packages/ibapi-10.22.1-py3.8.egg/ibapi/decoder.py:1387, in Decoder.interpret(self, fields)
#    1385         self.interpretWithSignature(fields, handleInfo)
#    1386     elif handleInfo.processMeth is not None:
# -> 1387         handleInfo.processMeth(self, iter(fields))
#    1388 except BadMessage:
#    1389         theBadMsg = ",".join(fields)
#
# File ~/anaconda3/lib/python3.8/site-packages/ibapi-10.22.1-py3.8.egg/ibapi/decoder.py:1277, in Decoder.processErrorMsg(self, fields)
#    1274 if self.serverVersion >= MIN_SERVER_VER_ADVANCED_ORDER_REJECT:
#    1275     advancedOrderRejectJson = decode(str, fields, False, True)
# -> 1277 self.wrapper.error(reqId, errorCode, errorString, advancedOrderRejectJson)
#
# TypeError: error() takes 4 positional arguments but 5 were given
